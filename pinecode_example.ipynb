# %% [markdown]
# <a href="https://colab.research.google.com/github/karmanandan/vector_databse_examples/blob/main/pinecode_example.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -qU "pinecone-client[grpc]"==2.2.1 datasets==2.12.0 sentence-transformers==2.2.2

# %%
# load dataset
from datasets import load_dataset

dataset = load_dataset('quora',split='train[240000:290000]')
dataset
# Out:
# WARNING:datasets.builder:Found cached dataset quora (/root/.cache/huggingface/datasets/quora/default/0.0.0/36ba4cd42107f051a158016f1bea6ae3f4685c5df843529108a54e42d86c1e04)
# Dataset({
#     features: ['questions', 'is_duplicate'],
#     num_rows: 50000
# })

# %%
dataset[:5]
# Out:
# {'questions': [{'id': [207550, 351729],
#    'text': ['What is the truth of life?', "What's the evil truth of life?"]},
#   {'id': [33183, 351730],
#    'text': ['Which is the best smartphone under 20K in India?',
#     'Which is the best smartphone with in 20k in India?']},
#   {'id': [351731, 351732],
#    'text': ['Steps taken by Canadian government to improve literacy rate?',
#     'Can I send homemade herbal hair oil from India to US via postal or private courier services?']},
#   {'id': [37799, 94186],
#    'text': ['What is a good way to lose 30 pounds in 2 months?',
#     'What can I do to lose 30 pounds in 2 months?']},
#   {'id': [351733, 351734],
#    'text': ['Which of the following most accurately describes the translation of the graph y = (x+3)^2 -2 to the graph of y = (x -2)^2 +2?',
#     'How do you graph x + 2y = -2?']}],
#  'is_duplicate': [False, True, False, True, False]}

# %%
questions = []
for qn in dataset['questions']:
  questions.extend(qn['text'])

# remove duplicates
questions = list(set(questions))
len(questions)
# Out:
# 88919

# %%
print('\n'.join(questions[:5]))
# Out:
# Am I eligible for defence quota if my father was in the navy?
# How do we know that we're not living in a computer simulation?
# How were the IP addresses starting with 172 established?
# Why does Quora seemingly always tell me that my questions need improvement when they are clear and concise questions?
# Why do the Olympic winners bite their medals?

# %%
from sentence_transformers import SentenceTransformer

# %%
import torch

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'
device
# Out:
# 'cuda'

# %%
help(SentenceTransformer())
# Out:
# Help on SentenceTransformer in module sentence_transformers.SentenceTransformer object:
#
# class SentenceTransformer(torch.nn.modules.container.Sequential)
#  |  SentenceTransformer(model_name_or_path: Optional[str] = None, modules: Optional[Iterable[torch.nn.modules.module.Module]] = None, device: Optional[str] = None, cache_folder: Optional[str] = None, use_auth_token: Union[bool, str, NoneType] = None)
#  |
#  |  Loads or create a SentenceTransformer model, that can be used to map sentences / text to embeddings.
#  |
#  |  :param model_name_or_path: If it is a filepath on disc, it loads the model from that path. If it is not a path, it first tries to download a pre-trained SentenceTransformer model. If that fails, tries to construct a model from Huggingface models repository with that name.
#  |  :param modules: This parameter can be used to create custom SentenceTransformer models from scratch.
#  |  :param device: Device (like 'cuda' / 'cpu') that should be used for computation. If None, checks if a GPU can be used.
#  |  :param cache_folder: Path to store models
#  |  :param use_auth_token: HuggingFace authentication token to download private models.
#  |
#  |  Method resolution order:
#  |      SentenceTransformer
#  |      torch.nn.modules.container.Sequential
#  |      torch.nn.modules.module.Module
#  |      builtins.object
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, model_name_or_path: Optional[str] = None, modules: Optional[Iterable[torch.nn.modules.module.Module]] = None, device: Optional[str] = None, cache_folder: Optional[str] = None, use_auth_token: Union[bool, str, NoneType] = None)
#  |      Initializes internal Module state, shared by both nn.Module and ScriptModule.
#  |
#  |  encode(self, sentences: Union[str, List[str]], batch_size: int = 32, show_progress_bar: bool = None, output_value: str = 'sentence_embedding', convert_to_numpy: bool = True, convert_to_tensor: bool = False, device: str = None, normalize_embeddings: bool = False) -> Union[List[torch.Tensor], numpy.ndarray, torch.Tensor]
#  |      Computes sentence embeddings
#  |
#  |      :param sentences: the sentences to embed
#  |      :param batch_size: the batch size used for the computation
#  |      :param show_progress_bar: Output a progress bar when encode sentences
#  |      :param output_value:  Default sentence_embedding, to get sentence embeddings. Can be set to token_embeddings to get wordpiece token embeddings. Set to None, to get all output values
#  |      :param convert_to_numpy: If true, the output is a list of numpy vectors. Else, it is a list of pytorch tensors.
#  |      :param convert_to_tensor: If true, you get one large tensor as return. Overwrites any setting from convert_to_numpy
#  |      :param device: Which torch.device to use for the computation
#  |      :param normalize_embeddings: If set to true, returned vectors will have length 1. In that case, the faster dot-product (util.dot_score) instead of cosine similarity can be used.
#  |
#  |      :return:
#  |         By default, a list of tensors is returned. If convert_to_tensor, a stacked tensor is returned. If convert_to_numpy, a numpy matrix is returned.
#  |
#  |  encode_multi_process(self, sentences: List[str], pool: Dict[str, object], batch_size: int = 32, chunk_size: int = None)
#  |      This method allows to run encode() on multiple GPUs. The sentences are chunked into smaller packages
#  |      and sent to individual processes, which encode these on the different GPUs. This method is only suitable
#  |      for encoding large sets of sentences
#  |
#  |      :param sentences: List of sentences
#  |      :param pool: A pool of workers started with SentenceTransformer.start_multi_process_pool
#  |      :param batch_size: Encode sentences with batch size
#  |      :param chunk_size: Sentences are chunked and sent to the individual processes. If none, it determine a sensible size.
#  |      :return: Numpy matrix with all embeddings
#  |
#  |  evaluate(self, evaluator: sentence_transformers.evaluation.SentenceEvaluator.SentenceEvaluator, output_path: str = None)
#  |      Evaluate the model
#  |
#  |      :param evaluator:
#  |          the evaluator
#  |      :param output_path:
#  |          the evaluator can write the results to this path
#  |
#  |  fit(self, train_objectives: Iterable[Tuple[torch.utils.data.dataloader.DataLoader, torch.nn.modules.module.Module]], evaluator: sentence_transformers.evaluation.SentenceEvaluator.SentenceEvaluator = None, epochs: int = 1, steps_per_epoch=None, scheduler: str = 'WarmupLinear', warmup_steps: int = 10000, optimizer_class: Type[torch.optim.optimizer.Optimizer] = <class 'torch.optim.adamw.AdamW'>, optimizer_params: Dict[str, object] = {'lr': 2e-05}, weight_decay: float = 0.01, evaluation_steps: int = 0, output_path: str = None, save_best_model: bool = True, max_grad_norm: float = 1, use_amp: bool = False, callback: Callable[[float, int, int], NoneType] = None, show_progress_bar: bool = True, checkpoint_path: str = None, checkpoint_save_steps: int = 500, checkpoint_save_total_limit: int = 0)
#  |      Train the model with the given training objective
#  |      Each training objective is sampled in turn for one batch.
#  |      We sample only as many batches from each objective as there are in the smallest one
#  |      to make sure of equal training with each dataset.
#  |
#  |      :param train_objectives: Tuples of (DataLoader, LossFunction). Pass more than one for multi-task learning
#  |      :param evaluator: An evaluator (sentence_transformers.evaluation) evaluates the model performance during training on held-out dev data. It is used to determine the best model that is saved to disc.
#  |      :param epochs: Number of epochs for training
#  |      :param steps_per_epoch: Number of training steps per epoch. If set to None (default), one epoch is equal the DataLoader size from train_objectives.
#  |      :param scheduler: Learning rate scheduler. Available schedulers: constantlr, warmupconstant, warmuplinear, warmupcosine, warmupcosinewithhardrestarts
#  |      :param warmup_steps: Behavior depends on the scheduler. For WarmupLinear (default), the learning rate is increased from o up to the maximal learning rate. After these many training steps, the learning rate is decreased linearly back to zero.
#  |      :param optimizer_class: Optimizer
#  |      :param optimizer_params: Optimizer parameters
#  |      :param weight_decay: Weight decay for model parameters
#  |      :param evaluation_steps: If > 0, evaluate the model using evaluator after each number of training steps
#  |      :param output_path: Storage path for the model and evaluation files
#  |      :param save_best_model: If true, the best model (according to evaluator) is stored at output_path
#  |      :param max_grad_norm: Used for gradient normalization.
#  |      :param use_amp: Use Automatic Mixed Precision (AMP). Only for Pytorch >= 1.6.0
#  |      :param callback: Callback function that is invoked after each evaluation.
#  |              It must accept the following three parameters in this order:
#  |              `score`, `epoch`, `steps`
#  |      :param show_progress_bar: If True, output a tqdm progress bar
#  |      :param checkpoint_path: Folder to save checkpoints during training
#  |      :param checkpoint_save_steps: Will save a checkpoint after so many steps
#  |      :param checkpoint_save_total_limit: Total number of checkpoints to store
#  |
#  |  get_max_seq_length(self)
#  |      Returns the maximal sequence length for input the model accepts. Longer inputs will be truncated
#  |
#  |  get_sentence_embedding_dimension(self)
#  |
#  |  get_sentence_features(self, *features)
#  |
#  |  save(self, path: str, model_name: Optional[str] = None, create_model_card: bool = True, train_datasets: Optional[List[str]] = None)
#  |      Saves all elements for this seq. sentence embedder into different sub-folders
#  |      :param path: Path on disc
#  |      :param model_name: Optional model name
#  |      :param create_model_card: If True, create a README.md with basic information about this model
#  |      :param train_datasets: Optional list with the names of the datasets used to to train the model
#  |
#  |  save_to_hub(self, repo_name: str, organization: Optional[str] = None, private: Optional[bool] = None, commit_message: str = 'Add new SentenceTransformer model.', local_model_path: Optional[str] = None, exist_ok: bool = False, replace_model_card: bool = False, train_datasets: Optional[List[str]] = None)
#  |      Uploads all elements of this Sentence Transformer to a new HuggingFace Hub repository.
#  |
#  |      :param repo_name: Repository name for your model in the Hub.
#  |      :param organization:  Organization in which you want to push your model or tokenizer (you must be a member of this organization).
#  |      :param private: Set to true, for hosting a prive model
#  |      :param commit_message: Message to commit while pushing.
#  |      :param local_model_path: Path of the model locally. If set, this file path will be uploaded. Otherwise, the current model will be uploaded
#  |      :param exist_ok: If true, saving to an existing repository is OK. If false, saving only to a new repository is possible
#  |      :param replace_model_card: If true, replace an existing model card in the hub with the automatically created model card
#  |      :param train_datasets: Datasets used to train the model. If set, the datasets will be added to the model card in the Hub.
#  |      :return: The url of the commit of your model in the given repository.
#  |
#  |  smart_batching_collate(self, batch)
#  |      Transforms a batch from a SmartBatchingDataset to a batch of tensors for the model
#  |      Here, batch is a list of tuples: [(tokens, label), ...]
#  |
#  |      :param batch:
#  |          a batch from a SmartBatchingDataset
#  |      :return:
#  |          a batch of tensors for the model
#  |
#  |  start_multi_process_pool(self, target_devices: List[str] = None)
#  |      Starts multi process to process the encoding with several, independent processes.
#  |      This method is recommended if you want to encode on multiple GPUs. It is advised
#  |      to start only one process per GPU. This method works together with encode_multi_process
#  |
#  |      :param target_devices: PyTorch target devices, e.g. cuda:0, cuda:1... If None, all available CUDA devices will be used
#  |      :return: Returns a dict with the target processes, an input queue and and output queue.
#  |
#  |  tokenize(self, texts: Union[List[str], List[Dict], List[Tuple[str, str]]])
#  |      Tokenizes the texts
#  |
#  |  ----------------------------------------------------------------------
#  |  Static methods defined here:
#  |
#  |  load(input_path)
#  |
#  |  stop_multi_process_pool(pool)
#  |      Stops all processes started with start_multi_process_pool
#  |
#  |  ----------------------------------------------------------------------
#  |  Readonly properties defined here:
#  |
#  |  device
#  |      Get torch.device from module, assuming that the whole module has one device.
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors defined here:
#  |
#  |  max_seq_length
#  |      Property to get the maximal input sequence length for the model. Longer inputs will be truncated.
#  |
#  |  tokenizer
#  |      Property to get the tokenizer that is used by this model
#  |
#  |  ----------------------------------------------------------------------
#  |  Data and other attributes defined here:
#  |
#  |  __annotations__ = {}
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from torch.nn.modules.container.Sequential:
#  |
#  |  __add__(self, other) -> 'Sequential'
#  |
#  |  __delitem__(self, idx: Union[slice, int]) -> None
#  |
#  |  __dir__(self)
#  |      Default dir() implementation.
#  |
#  |  __getitem__(self, idx: Union[slice, int]) -> Union[ForwardRef('Sequential'), ~T]
#  |
#  |  __iadd__(self, other) -> 'Sequential'
#  |
#  |  __imul__(self, other: int) -> 'Sequential'
#  |
#  |  __iter__(self) -> Iterator[torch.nn.modules.module.Module]
#  |
#  |  __len__(self) -> int
#  |
#  |  __mul__(self, other: int) -> 'Sequential'
#  |
#  |  __rmul__(self, other: int) -> 'Sequential'
#  |
#  |  __setitem__(self, idx: int, module: torch.nn.modules.module.Module) -> None
#  |
#  |  append(self, module: torch.nn.modules.module.Module) -> 'Sequential'
#  |      Appends a given module to the end.
#  |
#  |      Args:
#  |          module (nn.Module): module to append
#  |
#  |  extend(self, sequential) -> 'Sequential'
#  |
#  |  forward(self, input)
#  |      Defines the computation performed at every call.
#  |
#  |      Should be overridden by all subclasses.
#  |
#  |      .. note::
#  |          Although the recipe for forward pass needs to be defined within
#  |          this function, one should call the :class:`Module` instance afterwards
#  |          instead of this since the former takes care of running the
#  |          registered hooks while the latter silently ignores them.
#  |
#  |  insert(self, index: int, module: torch.nn.modules.module.Module) -> 'Sequential'
#  |
#  |  pop(self, key: Union[int, slice]) -> torch.nn.modules.module.Module
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from torch.nn.modules.module.Module:
#  |
#  |  __call__ = _call_impl(self, *args, **kwargs)
#  |
#  |  __delattr__(self, name)
#  |      Implement delattr(self, name).
#  |
#  |  __getattr__(self, name: str) -> Union[torch.Tensor, ForwardRef('Module')]
#  |
#  |  __repr__(self)
#  |      Return repr(self).
#  |
#  |  __setattr__(self, name: str, value: Union[torch.Tensor, ForwardRef('Module')]) -> None
#  |      Implement setattr(self, name, value).
#  |
#  |  __setstate__(self, state)
#  |
#  |  add_module(self, name: str, module: Optional[ForwardRef('Module')]) -> None
#  |      Adds a child module to the current module.
#  |
#  |      The module can be accessed as an attribute using the given name.
#  |
#  |      Args:
#  |          name (str): name of the child module. The child module can be
#  |              accessed from this module using the given name
#  |          module (Module): child module to be added to the module.
#  |
#  |  apply(self: ~T, fn: Callable[[ForwardRef('Module')], NoneType]) -> ~T
#  |      Applies ``fn`` recursively to every submodule (as returned by ``.children()``)
#  |      as well as self. Typical use includes initializing the parameters of a model
#  |      (see also :ref:`nn-init-doc`).
#  |
#  |      Args:
#  |          fn (:class:`Module` -> None): function to be applied to each submodule
#  |
#  |      Returns:
#  |          Module: self
#  |
#  |      Example::
#  |
#  |          >>> @torch.no_grad()
#  |          >>> def init_weights(m):
#  |          >>>     print(m)
#  |          >>>     if type(m) == nn.Linear:
#  |          >>>         m.weight.fill_(1.0)
#  |          >>>         print(m.weight)
#  |          >>> net = nn.Sequential(nn.Linear(2, 2), nn.Linear(2, 2))
#  |          >>> net.apply(init_weights)
#  |          Linear(in_features=2, out_features=2, bias=True)
#  |          Parameter containing:
#  |          tensor([[1., 1.],
#  |                  [1., 1.]], requires_grad=True)
#  |          Linear(in_features=2, out_features=2, bias=True)
#  |          Parameter containing:
#  |          tensor([[1., 1.],
#  |                  [1., 1.]], requires_grad=True)
#  |          Sequential(
#  |            (0): Linear(in_features=2, out_features=2, bias=True)
#  |            (1): Linear(in_features=2, out_features=2, bias=True)
#  |          )
#  |
#  |  bfloat16(self: ~T) -> ~T
#  |      Casts all floating point parameters and buffers to ``bfloat16`` datatype.
#  |
#  |      .. note::
#  |          This method modifies the module in-place.
#  |
#  |      Returns:
#  |          Module: self
#  |
#  |  buffers(self, recurse: bool = True) -> Iterator[torch.Tensor]
#  |      Returns an iterator over module buffers.
#  |
#  |      Args:
#  |          recurse (bool): if True, then yields buffers of this module
#  |              and all submodules. Otherwise, yields only buffers that
#  |              are direct members of this module.
#  |
#  |      Yields:
#  |          torch.Tensor: module buffer
#  |
#  |      Example::
#  |
#  |          >>> # xdoctest: +SKIP("undefined vars")
#  |          >>> for buf in model.buffers():
#  |          >>>     print(type(buf), buf.size())
#  |          <class 'torch.Tensor'> (20L,)
#  |          <class 'torch.Tensor'> (20L, 1L, 5L, 5L)
#  |
#  |  children(self) -> Iterator[ForwardRef('Module')]
#  |      Returns an iterator over immediate children modules.
#  |
#  |      Yields:
#  |          Module: a child module
#  |
#  |  cpu(self: ~T) -> ~T
#  |      Moves all model parameters and buffers to the CPU.
#  |
#  |      .. note::
#  |          This method modifies the module in-place.
#  |
#  |      Returns:
#  |          Module: self
#  |
#  |  cuda(self: ~T, device: Union[int, torch.device, NoneType] = None) -> ~T
#  |      Moves all model parameters and buffers to the GPU.
#  |
#  |      This also makes associated parameters and buffers different objects. So
#  |      it should be called before constructing optimizer if the module will
#  |      live on GPU while being optimized.
#  |
#  |      .. note::
#  |          This method modifies the module in-place.
#  |
#  |      Args:
#  |          device (int, optional): if specified, all parameters will be
#  |              copied to that device
#  |
#  |      Returns:
#  |          Module: self
#  |
#  |  double(self: ~T) -> ~T
#  |      Casts all floating point parameters and buffers to ``double`` datatype.
#  |
#  |      .. note::
#  |          This method modifies the module in-place.
#  |
#  |      Returns:
#  |          Module: self
#  |
#  |  eval(self: ~T) -> ~T
#  |      Sets the module in evaluation mode.
#  |
#  |      This has any effect only on certain modules. See documentations of
#  |      particular modules for details of their behaviors in training/evaluation
#  |      mode, if they are affected, e.g. :class:`Dropout`, :class:`BatchNorm`,
#  |      etc.
#  |
#  |      This is equivalent with :meth:`self.train(False) <torch.nn.Module.train>`.
#  |
#  |      See :ref:`locally-disable-grad-doc` for a comparison between
#  |      `.eval()` and several similar mechanisms that may be confused with it.
#  |
#  |      Returns:
#  |          Module: self
#  |
#  |  extra_repr(self) -> str
#  |      Set the extra representation of the module
#  |
#  |      To print customized extra information, you should re-implement
#  |      this method in your own modules. Both single-line and multi-line
#  |      strings are acceptable.
#  |
#  |  float(self: ~T) -> ~T
#  |      Casts all floating point parameters and buffers to ``float`` datatype.
#  |
#  |      .. note::
#  |          This method modifies the module in-place.
#  |
#  |      Returns:
#  |          Module: self
#  |
#  |  get_buffer(self, target: str) -> 'Tensor'
#  |      Returns the buffer given by ``target`` if it exists,
#  |      otherwise throws an error.
#  |
#  |      See the docstring for ``get_submodule`` for a more detailed
#  |      explanation of this method's functionality as well as how to
#  |      correctly specify ``target``.
#  |
#  |      Args:
#  |          target: The fully-qualified string name of the buffer
#  |              to look for. (See ``get_submodule`` for how to specify a
#  |              fully-qualified string.)
#  |
#  |      Returns:
#  |          torch.Tensor: The buffer referenced by ``target``
#  |
#  |      Raises:
#  |          AttributeError: If the target string references an invalid
#  |              path or resolves to something that is not a
#  |              buffer
#  |
#  |  get_extra_state(self) -> Any
#  |      Returns any extra state to include in the module's state_dict.
#  |      Implement this and a corresponding :func:`set_extra_state` for your module
#  |      if you need to store extra state. This function is called when building the
#  |      module's `state_dict()`.
#  |
#  |      Note that extra state should be picklable to ensure working serialization
#  |      of the state_dict. We only provide provide backwards compatibility guarantees
#  |      for serializing Tensors; other objects may break backwards compatibility if
#  |      their serialized pickled form changes.
#  |
#  |      Returns:
#  |          object: Any extra state to store in the module's state_dict
#  |
#  |  get_parameter(self, target: str) -> 'Parameter'
#  |      Returns the parameter given by ``target`` if it exists,
#  |      otherwise throws an error.
#  |
#  |      See the docstring for ``get_submodule`` for a more detailed
#  |      explanation of this method's functionality as well as how to
#  |      correctly specify ``target``.
#  |
#  |      Args:
#  |          target: The fully-qualified string name of the Parameter
#  |              to look for. (See ``get_submodule`` for how to specify a
#  |              fully-qualified string.)
#  |
#  |      Returns:
#  |          torch.nn.Parameter: The Parameter referenced by ``target``
#  |
#  |      Raises:
#  |          AttributeError: If the target string references an invalid
#  |              path or resolves to something that is not an
#  |              ``nn.Parameter``
#  |
#  |  get_submodule(self, target: str) -> 'Module'
#  |      Returns the submodule given by ``target`` if it exists,
#  |      otherwise throws an error.
#  |
#  |      For example, let's say you have an ``nn.Module`` ``A`` that
#  |      looks like this:
#  |
#  |      .. code-block:: text
#  |
#  |          A(
#  |              (net_b): Module(
#  |                  (net_c): Module(
#  |                      (conv): Conv2d(16, 33, kernel_size=(3, 3), stride=(2, 2))
#  |                  )
#  |                  (linear): Linear(in_features=100, out_features=200, bias=True)
#  |              )
#  |          )
#  |
#  |      (The diagram shows an ``nn.Module`` ``A``. ``A`` has a nested
#  |      submodule ``net_b``, which itself has two submodules ``net_c``
#  |      and ``linear``. ``net_c`` then has a submodule ``conv``.)
#  |
#  |      To check whether or not we have the ``linear`` submodule, we
#  |      would call ``get_submodule("net_b.linear")``. To check whether
#  |      we have the ``conv`` submodule, we would call
#  |      ``get_submodule("net_b.net_c.conv")``.
#  |
#  |      The runtime of ``get_submodule`` is bounded by the degree
#  |      of module nesting in ``target``. A query against
#  |      ``named_modules`` achieves the same result, but it is O(N) in
#  |      the number of transitive modules. So, for a simple check to see
#  |      if some submodule exists, ``get_submodule`` should always be
#  |      used.
#  |
#  |      Args:
#  |          target: The fully-qualified string name of the submodule
#  |              to look for. (See above example for how to specify a
#  |              fully-qualified string.)
#  |
#  |      Returns:
#  |          torch.nn.Module: The submodule referenced by ``target``
#  |
#  |      Raises:
#  |          AttributeError: If the target string references an invalid
#  |              path or resolves to something that is not an
#  |              ``nn.Module``
#  |
#  |  half(self: ~T) -> ~T
#  |      Casts all floating point parameters and buffers to ``half`` datatype.
#  |
#  |      .. note::
#  |          This method modifies the module in-place.
#  |
#  |      Returns:
#  |          Module: self
#  |
#  |  ipu(self: ~T, device: Union[int, torch.device, NoneType] = None) -> ~T
#  |      Moves all model parameters and buffers to the IPU.
#  |
#  |      This also makes associated parameters and buffers different objects. So
#  |      it should be called before constructing optimizer if the module will
#  |      live on IPU while being optimized.
#  |
#  |      .. note::
#  |          This method modifies the module in-place.
#  |
#  |      Arguments:
#  |          device (int, optional): if specified, all parameters will be
#  |              copied to that device
#  |
#  |      Returns:
#  |          Module: self
#  |
#  |  load_state_dict(self, state_dict: Mapping[str, Any], strict: bool = True)
#  |      Copies parameters and buffers from :attr:`state_dict` into
#  |      this module and its descendants. If :attr:`strict` is ``True``, then
#  |      the keys of :attr:`state_dict` must exactly match the keys returned
#  |      by this module's :meth:`~torch.nn.Module.state_dict` function.
#  |
#  |      Args:
#  |          state_dict (dict): a dict containing parameters and
#  |              persistent buffers.
#  |          strict (bool, optional): whether to strictly enforce that the keys
#  |              in :attr:`state_dict` match the keys returned by this module's
#  |              :meth:`~torch.nn.Module.state_dict` function. Default: ``True``
#  |
#  |      Returns:
#  |          ``NamedTuple`` with ``missing_keys`` and ``unexpected_keys`` fields:
#  |              * **missing_keys** is a list of str containing the missing keys
#  |              * **unexpected_keys** is a list of str containing the unexpected keys
#  |
#  |      Note:
#  |          If a parameter or buffer is registered as ``None`` and its corresponding key
#  |          exists in :attr:`state_dict`, :meth:`load_state_dict` will raise a
#  |          ``RuntimeError``.
#  |
#  |  modules(self) -> Iterator[ForwardRef('Module')]
#  |      Returns an iterator over all modules in the network.
#  |
#  |      Yields:
#  |          Module: a module in the network
#  |
#  |      Note:
#  |          Duplicate modules are returned only once. In the following
#  |          example, ``l`` will be returned only once.
#  |
#  |      Example::
#  |
#  |          >>> l = nn.Linear(2, 2)
#  |          >>> net = nn.Sequential(l, l)
#  |          >>> for idx, m in enumerate(net.modules()):
#  |          ...     print(idx, '->', m)
#  |
#  |          0 -> Sequential(
#  |            (0): Linear(in_features=2, out_features=2, bias=True)
#  |            (1): Linear(in_features=2, out_features=2, bias=True)
#  |          )
#  |          1 -> Linear(in_features=2, out_features=2, bias=True)
#  |
#  |  named_buffers(self, prefix: str = '', recurse: bool = True, remove_duplicate: bool = True) -> Iterator[Tuple[str, torch.Tensor]]
#  |      Returns an iterator over module buffers, yielding both the
#  |      name of the buffer as well as the buffer itself.
#  |
#  |      Args:
#  |          prefix (str): prefix to prepend to all buffer names.
#  |          recurse (bool, optional): if True, then yields buffers of this module
#  |              and all submodules. Otherwise, yields only buffers that
#  |              are direct members of this module. Defaults to True.
#  |          remove_duplicate (bool, optional): whether to remove the duplicated buffers in the result. Defaults to True.
#  |
#  |      Yields:
#  |          (str, torch.Tensor): Tuple containing the name and buffer
#  |
#  |      Example::
#  |
#  |          >>> # xdoctest: +SKIP("undefined vars")
#  |          >>> for name, buf in self.named_buffers():
#  |          >>>     if name in ['running_var']:
#  |          >>>         print(buf.size())
#  |
#  |  named_children(self) -> Iterator[Tuple[str, ForwardRef('Module')]]
#  |      Returns an iterator over immediate children modules, yielding both
#  |      the name of the module as well as the module itself.
#  |
#  |      Yields:
#  |          (str, Module): Tuple containing a name and child module
#  |
#  |      Example::
#  |
#  |          >>> # xdoctest: +SKIP("undefined vars")
#  |          >>> for name, module in model.named_children():
#  |          >>>     if name in ['conv4', 'conv5']:
#  |          >>>         print(module)
#  |
#  |  named_modules(self, memo: Optional[Set[ForwardRef('Module')]] = None, prefix: str = '', remove_duplicate: bool = True)
#  |      Returns an iterator over all modules in the network, yielding
#  |      both the name of the module as well as the module itself.
#  |
#  |      Args:
#  |          memo: a memo to store the set of modules already added to the result
#  |          prefix: a prefix that will be added to the name of the module
#  |          remove_duplicate: whether to remove the duplicated module instances in the result
#  |              or not
#  |
#  |      Yields:
#  |          (str, Module): Tuple of name and module
#  |
#  |      Note:
#  |          Duplicate modules are returned only once. In the following
#  |          example, ``l`` will be returned only once.
#  |
#  |      Example::
#  |
#  |          >>> l = nn.Linear(2, 2)
#  |          >>> net = nn.Sequential(l, l)
#  |          >>> for idx, m in enumerate(net.named_modules()):
#  |          ...     print(idx, '->', m)
#  |
#  |          0 -> ('', Sequential(
#  |            (0): Linear(in_features=2, out_features=2, bias=True)
#  |            (1): Linear(in_features=2, out_features=2, bias=True)
#  |          ))
#  |          1 -> ('0', Linear(in_features=2, out_features=2, bias=True))
#  |
#  |  named_parameters(self, prefix: str = '', recurse: bool = True, remove_duplicate: bool = True) -> Iterator[Tuple[str, torch.nn.parameter.Parameter]]
#  |      Returns an iterator over module parameters, yielding both the
#  |      name of the parameter as well as the parameter itself.
#  |
#  |      Args:
#  |          prefix (str): prefix to prepend to all parameter names.
#  |          recurse (bool): if True, then yields parameters of this module
#  |              and all submodules. Otherwise, yields only parameters that
#  |              are direct members of this module.
#  |          remove_duplicate (bool, optional): whether to remove the duplicated
#  |              parameters in the result. Defaults to True.
#  |
#  |      Yields:
#  |          (str, Parameter): Tuple containing the name and parameter
#  |
#  |      Example::
#  |
#  |          >>> # xdoctest: +SKIP("undefined vars")
#  |          >>> for name, param in self.named_parameters():
#  |          >>>     if name in ['bias']:
#  |          >>>         print(param.size())
#  |
#  |  parameters(self, recurse: bool = True) -> Iterator[torch.nn.parameter.Parameter]
#  |      Returns an iterator over module parameters.
#  |
#  |      This is typically passed to an optimizer.
#  |
#  |      Args:
#  |          recurse (bool): if True, then yields parameters of this module
#  |              and all submodules. Otherwise, yields only parameters that
#  |              are direct members of this module.
#  |
#  |      Yields:
#  |          Parameter: module parameter
#  |
#  |      Example::
#  |
#  |          >>> # xdoctest: +SKIP("undefined vars")
#  |          >>> for param in model.parameters():
#  |          >>>     print(type(param), param.size())
#  |          <class 'torch.Tensor'> (20L,)
#  |          <class 'torch.Tensor'> (20L, 1L, 5L, 5L)
#  |
#  |  register_backward_hook(self, hook: Callable[[ForwardRef('Module'), Union[Tuple[torch.Tensor, ...], torch.Tensor], Union[Tuple[torch.Tensor, ...], torch.Tensor]], Union[NoneType, Tuple[torch.Tensor, ...], torch.Tensor]]) -> torch.utils.hooks.RemovableHandle
#  |      Registers a backward hook on the module.
#  |
#  |      This function is deprecated in favor of :meth:`~torch.nn.Module.register_full_backward_hook` and
#  |      the behavior of this function will change in future versions.
#  |
#  |      Returns:
#  |          :class:`torch.utils.hooks.RemovableHandle`:
#  |              a handle that can be used to remove the added hook by calling
#  |              ``handle.remove()``
#  |
#  |  register_buffer(self, name: str, tensor: Optional[torch.Tensor], persistent: bool = True) -> None
#  |      Adds a buffer to the module.
#  |
#  |      This is typically used to register a buffer that should not to be
#  |      considered a model parameter. For example, BatchNorm's ``running_mean``
#  |      is not a parameter, but is part of the module's state. Buffers, by
#  |      default, are persistent and will be saved alongside parameters. This
#  |      behavior can be changed by setting :attr:`persistent` to ``False``. The
#  |      only difference between a persistent buffer and a non-persistent buffer
#  |      is that the latter will not be a part of this module's
#  |      :attr:`state_dict`.
#  |
#  |      Buffers can be accessed as attributes using given names.
#  |
#  |      Args:
#  |          name (str): name of the buffer. The buffer can be accessed
#  |              from this module using the given name
#  |          tensor (Tensor or None): buffer to be registered. If ``None``, then operations
#  |              that run on buffers, such as :attr:`cuda`, are ignored. If ``None``,
#  |              the buffer is **not** included in the module's :attr:`state_dict`.
#  |          persistent (bool): whether the buffer is part of this module's
#  |              :attr:`state_dict`.
#  |
#  |      Example::
#  |
#  |          >>> # xdoctest: +SKIP("undefined vars")
#  |          >>> self.register_buffer('running_mean', torch.zeros(num_features))
#  |
#  |  register_forward_hook(self, hook: Union[Callable[[~T, Tuple[Any, ...], Any], Optional[Any]], Callable[[~T, Tuple[Any, ...], Dict[str, Any], Any], Optional[Any]]], *, prepend: bool = False, with_kwargs: bool = False) -> torch.utils.hooks.RemovableHandle
#  |      Registers a forward hook on the module.
#  |
#  |      The hook will be called every time after :func:`forward` has computed an output.
#  |
#  |      If ``with_kwargs`` is ``False`` or not specified, the input contains only
#  |      the positional arguments given to the module. Keyword arguments won't be
#  |      passed to the hooks and only to the ``forward``. The hook can modify the
#  |      output. It can modify the input inplace but it will not have effect on
#  |      forward since this is called after :func:`forward` is called. The hook
#  |      should have the following signature::
#  |
#  |          hook(module, args, output) -> None or modified output
#  |
#  |      If ``with_kwargs`` is ``True``, the forward hook will be passed the
#  |      ``kwargs`` given to the forward function and be expected to return the
#  |      output possibly modified. The hook should have the following signature::
#  |
#  |          hook(module, args, kwargs, output) -> None or modified output
#  |
#  |      Args:
#  |          hook (Callable): The user defined hook to be registered.
#  |          prepend (bool): If ``True``, the provided ``hook`` will be fired
#  |              before all existing ``forward`` hooks on this
#  |              :class:`torch.nn.modules.Module`. Otherwise, the provided
#  |              ``hook`` will be fired after all existing ``forward`` hooks on
#  |              this :class:`torch.nn.modules.Module`. Note that global
#  |              ``forward`` hooks registered with
#  |              :func:`register_module_forward_hook` will fire before all hooks
#  |              registered by this method.
#  |              Default: ``False``
#  |          with_kwargs (bool): If ``True``, the ``hook`` will be passed the
#  |              kwargs given to the forward function.
#  |              Default: ``False``
#  |
#  |      Returns:
#  |          :class:`torch.utils.hooks.RemovableHandle`:
#  |              a handle that can be used to remove the added hook by calling
#  |              ``handle.remove()``
#  |
#  |  register_forward_pre_hook(self, hook: Union[Callable[[~T, Tuple[Any, ...]], Optional[Any]], Callable[[~T, Tuple[Any, ...], Dict[str, Any]], Optional[Tuple[Any, Dict[str, Any]]]]], *, prepend: bool = False, with_kwargs: bool = False) -> torch.utils.hooks.RemovableHandle
#  |      Registers a forward pre-hook on the module.
#  |
#  |      The hook will be called every time before :func:`forward` is invoked.
#  |
#  |
#  |      If ``with_kwargs`` is false or not specified, the input contains only
#  |      the positional arguments given to the module. Keyword arguments won't be
#  |      passed to the hooks and only to the ``forward``. The hook can modify the
#  |      input. User can either return a tuple or a single modified value in the
#  |      hook. We will wrap the value into a tuple if a single value is returned
#  |      (unless that value is already a tuple). The hook should have the
#  |      following signature::
#  |
#  |          hook(module, args) -> None or modified input
#  |
#  |      If ``with_kwargs`` is true, the forward pre-hook will be passed the
#  |      kwargs given to the forward function. And if the hook modifies the
#  |      input, both the args and kwargs should be returned. The hook should have
#  |      the following signature::
#  |
#  |          hook(module, args, kwargs) -> None or a tuple of modified input and kwargs
#  |
#  |      Args:
#  |          hook (Callable): The user defined hook to be registered.
#  |          prepend (bool): If true, the provided ``hook`` will be fired before
#  |              all existing ``forward_pre`` hooks on this
#  |              :class:`torch.nn.modules.Module`. Otherwise, the provided
#  |              ``hook`` will be fired after all existing ``forward_pre`` hooks
#  |              on this :class:`torch.nn.modules.Module`. Note that global
#  |              ``forward_pre`` hooks registered with
#  |              :func:`register_module_forward_pre_hook` will fire before all
#  |              hooks registered by this method.
#  |              Default: ``False``
#  |          with_kwargs (bool): If true, the ``hook`` will be passed the kwargs
#  |              given to the forward function.
#  |              Default: ``False``
#  |
#  |      Returns:
#  |          :class:`torch.utils.hooks.RemovableHandle`:
#  |              a handle that can be used to remove the added hook by calling
#  |              ``handle.remove()``
#  |
#  |  register_full_backward_hook(self, hook: Callable[[ForwardRef('Module'), Union[Tuple[torch.Tensor, ...], torch.Tensor], Union[Tuple[torch.Tensor, ...], torch.Tensor]], Union[NoneType, Tuple[torch.Tensor, ...], torch.Tensor]], prepend: bool = False) -> torch.utils.hooks.RemovableHandle
#  |      Registers a backward hook on the module.
#  |
#  |      The hook will be called every time the gradients with respect to a module
#  |      are computed, i.e. the hook will execute if and only if the gradients with
#  |      respect to module outputs are computed. The hook should have the following
#  |      signature::
#  |
#  |          hook(module, grad_input, grad_output) -> tuple(Tensor) or None
#  |
#  |      The :attr:`grad_input` and :attr:`grad_output` are tuples that contain the gradients
#  |      with respect to the inputs and outputs respectively. The hook should
#  |      not modify its arguments, but it can optionally return a new gradient with
#  |      respect to the input that will be used in place of :attr:`grad_input` in
#  |      subsequent computations. :attr:`grad_input` will only correspond to the inputs given
#  |      as positional arguments and all kwarg arguments are ignored. Entries
#  |      in :attr:`grad_input` and :attr:`grad_output` will be ``None`` for all non-Tensor
#  |      arguments.
#  |
#  |      For technical reasons, when this hook is applied to a Module, its forward function will
#  |      receive a view of each Tensor passed to the Module. Similarly the caller will receive a view
#  |      of each Tensor returned by the Module's forward function.
#  |
#  |      .. warning ::
#  |          Modifying inputs or outputs inplace is not allowed when using backward hooks and
#  |          will raise an error.
#  |
#  |      Args:
#  |          hook (Callable): The user-defined hook to be registered.
#  |          prepend (bool): If true, the provided ``hook`` will be fired before
#  |              all existing ``backward`` hooks on this
#  |              :class:`torch.nn.modules.Module`. Otherwise, the provided
#  |              ``hook`` will be fired after all existing ``backward`` hooks on
#  |              this :class:`torch.nn.modules.Module`. Note that global
#  |              ``backward`` hooks registered with
#  |              :func:`register_module_full_backward_hook` will fire before
#  |              all hooks registered by this method.
#  |
#  |      Returns:
#  |          :class:`torch.utils.hooks.RemovableHandle`:
#  |              a handle that can be used to remove the added hook by calling
#  |              ``handle.remove()``
#  |
#  |  register_full_backward_pre_hook(self, hook: Callable[[ForwardRef('Module'), Union[Tuple[torch.Tensor, ...], torch.Tensor]], Union[NoneType, Tuple[torch.Tensor, ...], torch.Tensor]], prepend: bool = False) -> torch.utils.hooks.RemovableHandle
#  |      Registers a backward pre-hook on the module.
#  |
#  |      The hook will be called every time the gradients for the module are computed.
#  |      The hook should have the following signature::
#  |
#  |          hook(module, grad_output) -> Tensor or None
#  |
#  |      The :attr:`grad_output` is a tuple. The hook should
#  |      not modify its arguments, but it can optionally return a new gradient with
#  |      respect to the output that will be used in place of :attr:`grad_output` in
#  |      subsequent computations. Entries in :attr:`grad_output` will be ``None`` for
#  |      all non-Tensor arguments.
#  |
#  |      For technical reasons, when this hook is applied to a Module, its forward function will
#  |      receive a view of each Tensor passed to the Module. Similarly the caller will receive a view
#  |      of each Tensor returned by the Module's forward function.
#  |
#  |      .. warning ::
#  |          Modifying inputs inplace is not allowed when using backward hooks and
#  |          will raise an error.
#  |
#  |      Args:
#  |          hook (Callable): The user-defined hook to be registered.
#  |          prepend (bool): If true, the provided ``hook`` will be fired before
#  |              all existing ``backward_pre`` hooks on this
#  |              :class:`torch.nn.modules.Module`. Otherwise, the provided
#  |              ``hook`` will be fired after all existing ``backward_pre`` hooks
#  |              on this :class:`torch.nn.modules.Module`. Note that global
#  |              ``backward_pre`` hooks registered with
#  |              :func:`register_module_full_backward_pre_hook` will fire before
#  |              all hooks registered by this method.
#  |
#  |      Returns:
#  |          :class:`torch.utils.hooks.RemovableHandle`:
#  |              a handle that can be used to remove the added hook by calling
#  |              ``handle.remove()``
#  |
#  |  register_load_state_dict_post_hook(self, hook)
#  |      Registers a post hook to be run after module's ``load_state_dict``
#  |      is called.
#  |
#  |      It should have the following signature::
#  |          hook(module, incompatible_keys) -> None
#  |
#  |      The ``module`` argument is the current module that this hook is registered
#  |      on, and the ``incompatible_keys`` argument is a ``NamedTuple`` consisting
#  |      of attributes ``missing_keys`` and ``unexpected_keys``. ``missing_keys``
#  |      is a ``list`` of ``str`` containing the missing keys and
#  |      ``unexpected_keys`` is a ``list`` of ``str`` containing the unexpected keys.
#  |
#  |      The given incompatible_keys can be modified inplace if needed.
#  |
#  |      Note that the checks performed when calling :func:`load_state_dict` with
#  |      ``strict=True`` are affected by modifications the hook makes to
#  |      ``missing_keys`` or ``unexpected_keys``, as expected. Additions to either
#  |      set of keys will result in an error being thrown when ``strict=True``, and
#  |      clearing out both missing and unexpected keys will avoid an error.
#  |
#  |      Returns:
#  |          :class:`torch.utils.hooks.RemovableHandle`:
#  |              a handle that can be used to remove the added hook by calling
#  |              ``handle.remove()``
#  |
#  |  register_module(self, name: str, module: Optional[ForwardRef('Module')]) -> None
#  |      Alias for :func:`add_module`.
#  |
#  |  register_parameter(self, name: str, param: Optional[torch.nn.parameter.Parameter]) -> None
#  |      Adds a parameter to the module.
#  |
#  |      The parameter can be accessed as an attribute using given name.
#  |
#  |      Args:
#  |          name (str): name of the parameter. The parameter can be accessed
#  |              from this module using the given name
#  |          param (Parameter or None): parameter to be added to the module. If
#  |              ``None``, then operations that run on parameters, such as :attr:`cuda`,
#  |              are ignored. If ``None``, the parameter is **not** included in the
#  |              module's :attr:`state_dict`.
#  |
#  |  register_state_dict_pre_hook(self, hook)
#  |      These hooks will be called with arguments: ``self``, ``prefix``,
#  |      and ``keep_vars`` before calling ``state_dict`` on ``self``. The registered
#  |      hooks can be used to perform pre-processing before the ``state_dict``
#  |      call is made.
#  |
#  |  requires_grad_(self: ~T, requires_grad: bool = True) -> ~T
#  |      Change if autograd should record operations on parameters in this
#  |      module.
#  |
#  |      This method sets the parameters' :attr:`requires_grad` attributes
#  |      in-place.
#  |
#  |      This method is helpful for freezing part of the module for finetuning
#  |      or training parts of a model individually (e.g., GAN training).
#  |
#  |      See :ref:`locally-disable-grad-doc` for a comparison between
#  |      `.requires_grad_()` and several similar mechanisms that may be confused with it.
#  |
#  |      Args:
#  |          requires_grad (bool): whether autograd should record operations on
#  |                                parameters in this module. Default: ``True``.
#  |
#  |      Returns:
#  |          Module: self
#  |
#  |  set_extra_state(self, state: Any)
#  |      This function is called from :func:`load_state_dict` to handle any extra state
#  |      found within the `state_dict`. Implement this function and a corresponding
#  |      :func:`get_extra_state` for your module if you need to store extra state within its
#  |      `state_dict`.
#  |
#  |      Args:
#  |          state (dict): Extra state from the `state_dict`
#  |
#  |  share_memory(self: ~T) -> ~T
#  |      See :meth:`torch.Tensor.share_memory_`
#  |
#  |  state_dict(self, *args, destination=None, prefix='', keep_vars=False)
#  |      Returns a dictionary containing references to the whole state of the module.
#  |
#  |      Both parameters and persistent buffers (e.g. running averages) are
#  |      included. Keys are corresponding parameter and buffer names.
#  |      Parameters and buffers set to ``None`` are not included.
#  |
#  |      .. note::
#  |          The returned object is a shallow copy. It contains references
#  |          to the module's parameters and buffers.
#  |
#  |      .. warning::
#  |          Currently ``state_dict()`` also accepts positional arguments for
#  |          ``destination``, ``prefix`` and ``keep_vars`` in order. However,
#  |          this is being deprecated and keyword arguments will be enforced in
#  |          future releases.
#  |
#  |      .. warning::
#  |          Please avoid the use of argument ``destination`` as it is not
#  |          designed for end-users.
#  |
#  |      Args:
#  |          destination (dict, optional): If provided, the state of module will
#  |              be updated into the dict and the same object is returned.
#  |              Otherwise, an ``OrderedDict`` will be created and returned.
#  |              Default: ``None``.
#  |          prefix (str, optional): a prefix added to parameter and buffer
#  |              names to compose the keys in state_dict. Default: ``''``.
#  |          keep_vars (bool, optional): by default the :class:`~torch.Tensor` s
#  |              returned in the state dict are detached from autograd. If it's
#  |              set to ``True``, detaching will not be performed.
#  |              Default: ``False``.
#  |
#  |      Returns:
#  |          dict:
#  |              a dictionary containing a whole state of the module
#  |
#  |      Example::
#  |
#  |          >>> # xdoctest: +SKIP("undefined vars")
#  |          >>> module.state_dict().keys()
#  |          ['bias', 'weight']
#  |
#  |  to(self, *args, **kwargs)
#  |      Moves and/or casts the parameters and buffers.
#  |
#  |      This can be called as
#  |
#  |      .. function:: to(device=None, dtype=None, non_blocking=False)
#  |         :noindex:
#  |
#  |      .. function:: to(dtype, non_blocking=False)
#  |         :noindex:
#  |
#  |      .. function:: to(tensor, non_blocking=False)
#  |         :noindex:
#  |
#  |      .. function:: to(memory_format=torch.channels_last)
#  |         :noindex:
#  |
#  |      Its signature is similar to :meth:`torch.Tensor.to`, but only accepts
#  |      floating point or complex :attr:`dtype`\ s. In addition, this method will
#  |      only cast the floating point or complex parameters and buffers to :attr:`dtype`
#  |      (if given). The integral parameters and buffers will be moved
#  |      :attr:`device`, if that is given, but with dtypes unchanged. When
#  |      :attr:`non_blocking` is set, it tries to convert/move asynchronously
#  |      with respect to the host if possible, e.g., moving CPU Tensors with
#  |      pinned memory to CUDA devices.
#  |
#  |      See below for examples.
#  |
#  |      .. note::
#  |          This method modifies the module in-place.
#  |
#  |      Args:
#  |          device (:class:`torch.device`): the desired device of the parameters
#  |              and buffers in this module
#  |          dtype (:class:`torch.dtype`): the desired floating point or complex dtype of
#  |              the parameters and buffers in this module
#  |          tensor (torch.Tensor): Tensor whose dtype and device are the desired
#  |              dtype and device for all parameters and buffers in this module
#  |          memory_format (:class:`torch.memory_format`): the desired memory
#  |              format for 4D parameters and buffers in this module (keyword
#  |              only argument)
#  |
#  |      Returns:
#  |          Module: self
#  |
#  |      Examples::
#  |
#  |          >>> # xdoctest: +IGNORE_WANT("non-deterministic")
#  |          >>> linear = nn.Linear(2, 2)
#  |          >>> linear.weight
#  |          Parameter containing:
#  |          tensor([[ 0.1913, -0.3420],
#  |                  [-0.5113, -0.2325]])
#  |          >>> linear.to(torch.double)
#  |          Linear(in_features=2, out_features=2, bias=True)
#  |          >>> linear.weight
#  |          Parameter containing:
#  |          tensor([[ 0.1913, -0.3420],
#  |                  [-0.5113, -0.2325]], dtype=torch.float64)
#  |          >>> # xdoctest: +REQUIRES(env:TORCH_DOCTEST_CUDA1)
#  |          >>> gpu1 = torch.device("cuda:1")
#  |          >>> linear.to(gpu1, dtype=torch.half, non_blocking=True)
#  |          Linear(in_features=2, out_features=2, bias=True)
#  |          >>> linear.weight
#  |          Parameter containing:
#  |          tensor([[ 0.1914, -0.3420],
#  |                  [-0.5112, -0.2324]], dtype=torch.float16, device='cuda:1')
#  |          >>> cpu = torch.device("cpu")
#  |          >>> linear.to(cpu)
#  |          Linear(in_features=2, out_features=2, bias=True)
#  |          >>> linear.weight
#  |          Parameter containing:
#  |          tensor([[ 0.1914, -0.3420],
#  |                  [-0.5112, -0.2324]], dtype=torch.float16)
#  |
#  |          >>> linear = nn.Linear(2, 2, bias=None).to(torch.cdouble)
#  |          >>> linear.weight
#  |          Parameter containing:
#  |          tensor([[ 0.3741+0.j,  0.2382+0.j],
#  |                  [ 0.5593+0.j, -0.4443+0.j]], dtype=torch.complex128)
#  |          >>> linear(torch.ones(3, 2, dtype=torch.cdouble))
#  |          tensor([[0.6122+0.j, 0.1150+0.j],
#  |                  [0.6122+0.j, 0.1150+0.j],
#  |                  [0.6122+0.j, 0.1150+0.j]], dtype=torch.complex128)
#  |
#  |  to_empty(self: ~T, *, device: Union[str, torch.device]) -> ~T
#  |      Moves the parameters and buffers to the specified device without copying storage.
#  |
#  |      Args:
#  |          device (:class:`torch.device`): The desired device of the parameters
#  |              and buffers in this module.
#  |
#  |      Returns:
#  |          Module: self
#  |
#  |  train(self: ~T, mode: bool = True) -> ~T
#  |      Sets the module in training mode.
#  |
#  |      This has any effect only on certain modules. See documentations of
#  |      particular modules for details of their behaviors in training/evaluation
#  |      mode, if they are affected, e.g. :class:`Dropout`, :class:`BatchNorm`,
#  |      etc.
#  |
#  |      Args:
#  |          mode (bool): whether to set training mode (``True``) or evaluation
#  |                       mode (``False``). Default: ``True``.
#  |
#  |      Returns:
#  |          Module: self
#  |
#  |  type(self: ~T, dst_type: Union[torch.dtype, str]) -> ~T
#  |      Casts all parameters and buffers to :attr:`dst_type`.
#  |
#  |      .. note::
#  |          This method modifies the module in-place.
#  |
#  |      Args:
#  |          dst_type (type or string): the desired type
#  |
#  |      Returns:
#  |          Module: self
#  |
#  |  xpu(self: ~T, device: Union[int, torch.device, NoneType] = None) -> ~T
#  |      Moves all model parameters and buffers to the XPU.
#  |
#  |      This also makes associated parameters and buffers different objects. So
#  |      it should be called before constructing optimizer if the module will
#  |      live on XPU while being optimized.
#  |
#  |      .. note::
#  |          This method modifies the module in-place.
#  |
#  |      Arguments:
#  |          device (int, optional): if specified, all parameters will be
#  |              copied to that device
#  |
#  |      Returns:
#  |          Module: self
#  |
#  |  zero_grad(self, set_to_none: bool = True) -> None
#  |      Sets gradients of all model parameters to zero. See similar function
#  |      under :class:`torch.optim.Optimizer` for more context.
#  |
#  |      Args:
#  |          set_to_none (bool): instead of setting to zero, set the grads to None.
#  |              See :meth:`torch.optim.Optimizer.zero_grad` for details.
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors inherited from torch.nn.modules.module.Module:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)
#  |
#  |  ----------------------------------------------------------------------
#  |  Data and other attributes inherited from torch.nn.modules.module.Module:
#  |
#  |  T_destination = ~T_destination
#  |
#  |  call_super_init = False
#  |
#  |  dump_patches = False

# %%
model = SentenceTransformer('all-MiniLM-L6-V2',device=device)
model
# Out:
# SentenceTransformer(
#   (0): Transformer({'max_seq_length': 256, 'do_lower_case': False}) with Transformer model: BertModel
#   (1): Pooling({'word_embedding_dimension': 384, 'pooling_mode_cls_token': False, 'pooling_mode_mean_tokens': True, 'pooling_mode_max_tokens': False, 'pooling_mode_mean_sqrt_len_tokens': False})
#   (2): Normalize()
# )

# %%
print("max_seq_length:",model.max_seq_length)
# Out:
# max_seq_length: 256

# %%
query = 'who is the writer for animal farm'
query_embed = model.encode(query)
# query_embed

# %%
query_embed.shape
# Out:
# (384,)

# %%
_id = '0'
meta_data = {'text':query}
vectors = [(_id, query_embed, meta_data)]
vectors
# Out:
# [('0',
#   array([-6.12460338e-02, -2.82994285e-02,  1.76846609e-02,  3.87213640e-02,
#           1.00621330e-02,  2.29025371e-02, -5.57215251e-02, -4.20217812e-02,
#           1.29571920e-02,  1.29865250e-02,  5.03526255e-02,  6.09714799e-02,
#          -5.33461608e-02, -6.55398518e-03, -5.59711009e-02,  7.55332857e-02,
#          -4.53792438e-02,  6.75516576e-02,  4.66930754e-02, -5.91803342e-02,
#          -5.12790494e-02,  3.11999731e-02, -8.13353341e-03,  1.49146840e-03,
#          -2.14882735e-02, -5.42149693e-02, -1.61097888e-02, -2.43777335e-02,
#          -1.08334802e-01,  2.56306268e-02, -3.06039751e-02,  3.85068506e-02,
#           1.11974590e-02,  1.27367089e-02,  4.45901789e-02,  5.56536764e-02,
#           1.76930521e-02, -8.36187694e-03,  5.60073704e-02,  1.37353328e-03,
#           2.60696504e-02, -9.27120522e-02, -1.48614459e-02, -3.33702890e-03,
#          -2.20804345e-02, -3.40280123e-02, -2.18813214e-02, -9.12155211e-02,
#           3.02205049e-02, -3.66846398e-02, -3.97559591e-02, -3.49009261e-02,
#           1.04891360e-02, -9.75453258e-02, -2.75350697e-02, -9.41793807e-03,
#           3.49064916e-03,  4.59741987e-02,  8.84171051e-04, -6.13673739e-02,
#           6.81923181e-02, -3.09586469e-02,  2.84571871e-02,  5.81168830e-02,
#           8.56241956e-02,  1.45966429e-02, -7.52266794e-02,  7.92754740e-02,
#          -8.69076848e-02, -1.01665132e-01, -4.44034534e-03, -3.33241373e-02,
#           2.78863981e-02, -5.92582747e-02, -1.66294090e-02,  3.77507284e-02,
#          -5.08717857e-02, -1.87766291e-02,  1.40770584e-01, -4.56662513e-02,
#           3.70723642e-02, -7.69617110e-02, -5.68739139e-03, -1.88956335e-02,
#          -1.62052233e-02,  1.22429458e-02,  3.27351056e-02,  3.42792496e-02,
#           5.01480047e-03, -5.49003249e-03,  2.47063562e-02, -1.07966796e-01,
#           3.27738794e-03,  4.00945246e-02,  4.91300179e-03,  5.31330220e-02,
#          -3.81703228e-02, -3.95923443e-02, -6.03962913e-02, -8.46279319e-03,
#          -3.37722413e-02, -4.41439711e-02,  3.77421081e-02, -1.03761196e-01,
#           1.00266583e-01, -4.07928228e-02, -7.51810893e-02,  4.19059843e-02,
#          -2.17920765e-02,  3.41504775e-02, -4.68352214e-02,  3.81202586e-02,
#          -6.12734407e-02,  1.11584939e-01,  1.36030942e-01,  4.35952507e-02,
#          -3.65514704e-03, -1.04926310e-01, -8.19791704e-02, -2.57371622e-03,
#           7.29646981e-02,  3.70453461e-03, -4.99862544e-02, -2.63976119e-02,
#           7.57569773e-03, -1.64670516e-02,  4.16777767e-02, -5.86112540e-33,
#           4.58085015e-02, -4.44676131e-02, -4.58263382e-02, -6.94121234e-03,
#           1.26859173e-01,  7.98302889e-03, -7.71639915e-03, -1.55961756e-02,
#          -2.93075480e-02, -5.10831084e-03, -3.73294204e-02,  3.83549882e-03,
#           4.80642878e-02, -3.77518870e-02, -7.80788064e-02, -4.19580787e-02,
#          -1.11596659e-02, -1.82210542e-02,  1.05488695e-01,  4.16516047e-03,
#           9.35719442e-03,  1.63987819e-02, -1.00253448e-01,  2.04421319e-02,
#           1.99438799e-02, -4.33529094e-02, -1.32268956e-02, -1.10780142e-01,
#           4.49601449e-02,  1.53690148e-02,  1.68605819e-02, -5.39778993e-02,
#          -3.32533047e-02, -2.04281658e-02, -2.45294049e-02, -9.11993459e-02,
#          -6.75239488e-02, -1.10534385e-01,  2.59046201e-02,  4.65519764e-02,
#           2.97841784e-02,  4.37502712e-02,  1.47921205e-01, -3.36861387e-02,
#          -2.76317466e-02,  8.63395929e-02,  2.57234983e-02,  8.32136795e-02,
#           5.98099343e-02,  6.48602545e-02,  3.09530925e-02,  2.93535106e-02,
#           2.00433098e-03, -2.68025454e-02,  7.44636282e-02, -5.28920768e-03,
#          -2.65912767e-02, -6.55218810e-02,  2.64157262e-03, -1.54166315e-02,
#           6.43761549e-03,  4.48937677e-02, -1.62307303e-02, -3.74143347e-02,
#           4.82888557e-02, -6.26288876e-02, -2.96628978e-02,  3.17874365e-02,
#          -6.07049577e-02,  9.46484730e-02,  3.64286490e-02, -4.40477245e-02,
#          -6.41803518e-02, -6.79313317e-02, -8.65346640e-02, -2.35041864e-02,
#           5.99731319e-02,  3.66936773e-02, -1.43271014e-01, -3.82553600e-02,
#           2.00999491e-02,  5.13818562e-02, -3.74464728e-02,  6.39993548e-02,
#          -8.62863958e-02,  6.01284280e-02, -1.13480063e-02,  1.20869633e-02,
#           4.24441397e-02,  1.53131559e-02,  8.82612094e-02, -9.56234429e-03,
#          -5.28639890e-02, -8.21766779e-02,  2.31909025e-02,  3.86988940e-33,
#          -4.98327427e-02, -6.01322837e-02,  3.47833708e-02,  3.22907232e-02,
#           3.97035619e-03, -1.79974865e-02,  1.76354479e-02,  5.71221076e-02,
#           6.77010864e-02,  1.33221848e-02, -3.23976576e-02,  5.51253669e-02,
#          -1.66818425e-02,  2.92460457e-03,  7.41960900e-03, -3.07333935e-02,
#          -6.00945838e-02, -6.98796734e-02,  5.41705340e-02, -5.25449142e-02,
#          -4.33038399e-02,  4.37428169e-02, -1.55422436e-02,  7.53540965e-03,
#           6.12732135e-02,  5.06050400e-02, -4.40965295e-02,  5.13390228e-02,
#          -3.25251110e-02, -7.49817938e-02,  1.55400892e-04,  1.81453303e-02,
#           5.51464781e-02, -1.56496894e-02, -1.89730059e-02,  1.63374078e-02,
#           2.73683146e-02, -6.50630593e-02,  2.45073391e-03, -7.59198284e-03,
#           1.23874642e-01, -4.14586514e-02, -1.19744428e-01, -1.34186521e-02,
#          -6.18583672e-02,  3.58083844e-02, -2.89423415e-03,  2.97707412e-02,
#           1.95791684e-02,  8.02508369e-02, -9.57606186e-04,  6.58996552e-02,
#           8.25213175e-03, -4.66246195e-02,  2.28446908e-02,  3.78525108e-02,
#           7.40949064e-02, -1.01504304e-01, -1.08854426e-02,  1.82276350e-02,
#          -5.56393666e-03,  9.15088225e-03,  4.27763350e-02,  3.19962949e-02,
#          -6.57502413e-02, -5.33315055e-02,  8.46639369e-03, -3.58024128e-02,
#           1.30979186e-02, -2.43065320e-02, -4.02728766e-02,  3.92069221e-02,
#           2.94535682e-02, -6.32779906e-03, -6.55322149e-02,  8.78592432e-02,
#           5.43412119e-02, -6.00846158e-03,  4.26120311e-02, -5.06200343e-02,
#           3.22312326e-03, -3.52609791e-02,  6.11065254e-02,  1.20406896e-01,
#           6.56037480e-02,  2.57121399e-02, -7.27322549e-02,  7.36324191e-02,
#           9.65956897e-02,  4.52283658e-02,  1.74872242e-02, -4.74326126e-02,
#           9.91560966e-02,  2.55614445e-02,  5.23666181e-02, -1.58740416e-08,
#          -6.62632883e-02, -5.87002635e-02,  4.02951315e-02, -3.34292054e-02,
#           7.27363005e-02,  8.42412636e-02, -3.09835728e-02, -6.26311004e-02,
#           2.33121659e-03,  1.20925285e-01, -5.59935765e-03,  5.84630445e-02,
#          -6.44481182e-02,  2.75646243e-02, -3.62792723e-02,  9.31056868e-03,
#           1.53456479e-01, -4.57737297e-02, -9.97306593e-03,  6.91258684e-02,
#          -1.32275932e-03,  5.46851084e-02, -4.17060219e-02, -5.96394204e-02,
#           4.95041013e-02,  9.87349078e-03, -4.74866712e-03, -3.93967852e-02,
#          -1.65338833e-02,  6.91770925e-04, -2.69951783e-02,  8.94626305e-02,
#           1.66337367e-03, -2.20780578e-02,  7.82480277e-03,  3.26662604e-03,
#           9.11041256e-03, -1.69014968e-02, -2.18452867e-02,  1.79241598e-02,
#          -1.28022293e-02,  8.64597708e-02,  6.41645715e-02, -1.32354805e-02,
#           4.57307249e-02, -2.73981150e-02,  4.24054749e-02,  1.48942024e-02,
#           2.10586321e-02, -2.03414187e-02, -6.16599433e-02,  6.39303494e-03,
#           1.01967253e-01, -3.56326289e-02, -2.20759436e-02,  2.02451763e-03,
#          -1.94790214e-02, -5.85445575e-02,  3.83278020e-02, -3.32430489e-02,
#          -1.79346632e-02, -1.78875551e-02,  2.50855070e-02, -3.88666578e-02],
#         dtype=float32),
#   {'text': 'who is the writer for animal farm'})]

# %%
len(questions)
# Out:
# 88919

# %%
import os
import pinecone

# get api key from app.pinecone.io
api_key = ''
# find your environment next to the api key in pinecone console
env = 'us-west1-gcp-free'

pinecone.init(
    api_key=api_key,
    environment=env
)

index_name = 'semantic-search'

# only create index if it doesn't exist
if index_name not in pinecone.list_indexes():
    pinecone.create_index(
        name=index_name,
        dimension=model.get_sentence_embedding_dimension(),
        metric='cosine'
    )

# now connect to the index
index = pinecone.GRPCIndex(index_name)

# %%
from tqdm.auto import tqdm

vector_limit = 80000

questions = questions[:vector_limit]

# %%
len(questions)
# Out:
# 80000

# %%
batch_size = 128

# %%
vector_db = []
for i in tqdm(range(0, len(questions), batch_size)):
  # find end of batch
  i_end = min(i+batch_size, len(questions))
  # create IDs batch
  ids = [str(x) for x in range(i,i_end)]
  # create metadata batch
  metadatas = [{'text':text} for text in questions[i:i_end]]
  # create embeddings
  xc = model.encode(questions[i:i_end])
  # upsert to Pinecone
  records = zip(ids, xc, metadatas)
  index.upsert(records)
  # vector_db.append(records)

# check number of records in the index
index.describe_index_stats()
# Out:
#   0%|          | 0/625 [00:00<?, ?it/s]
# {'dimension': 384,
#  'index_fullness': 0.2,
#  'namespaces': {'': {'vector_count': 80000}},
#  'total_vector_count': 80000}

# %%
# len(vector_db)
# Out:
# 0

# %%
625*128
# Out:
# 80000

# %%
query = 'Is it safe to smoke weed?'#"which city has the highest population in the world?"

# create the query vector
xq = model.encode(query).tolist()

# now query
xc = index.query(xq, top_k=5, include_metadata=True)
xc
# Out:
# {'matches': [{'id': '961',
#               'metadata': {'text': 'Is it safe to smoke weed?'},
#               'score': 1.0000001,
#               'sparse_values': {'indices': [], 'values': []},
#               'values': []},
#              {'id': '19542',
#               'metadata': {'text': 'I smoke weed. Is it really harmful? Should '
#                                    'I stop it?'},
#               'score': 0.82423276,
#               'sparse_values': {'indices': [], 'values': []},
#               'values': []},
#              {'id': '37052',
#               'metadata': {'text': 'Does smoking weed is bad for health?'},
#               'score': 0.8134777,
#               'sparse_values': {'indices': [], 'values': []},
#               'values': []},
#              {'id': '36290',
#               'metadata': {'text': 'Should I stop smoking weed?'},
#               'score': 0.74605834,
#               'sparse_values': {'indices': [], 'values': []},
#               'values': []},
#              {'id': '13068',
#               'metadata': {'text': 'Is it safe to smoke weed while on Prozac?'},
#               'score': 0.73270637,
#               'sparse_values': {'indices': [], 'values': []},
#               'values': []}],
#  'namespace': ''}

# %%
for result in xc['matches']:
    print(f"{round(result['score'], 2)}: {result['metadata']['text']}")
# Out:
# 1.0: Is it safe to smoke weed?
# 0.82: I smoke weed. Is it really harmful? Should I stop it?
# 0.81: Does smoking weed is bad for health?
# 0.75: Should I stop smoking weed?
# 0.73: Is it safe to smoke weed while on Prozac?

# %%
questions
# Out:
# ['Am I eligible for defence quota if my father was in the navy?',
#  "How do we know that we're not living in a computer simulation?",
#  'How were the IP addresses starting with 172 established?',
#  'Why does Quora seemingly always tell me that my questions need improvement when they are clear and concise questions?',
#  'Why do the Olympic winners bite their medals?',
#  'Which movie is better in your opinion, Godfather 1 or 2?',
#  'Is it safe to buy a laptop-online from Infibeam?',
#  'Can a minor sue or be sued?',
#  "My girlfriend's ex-boyfriend is trying to get her back, but she loves me and wants to stay with me. What should I do get rid of him?",
#  'Which college should I try for, to get a job in discovery channel? And which course should be opt for?',
#  'Is it necessary to transfer documents of bike from one state to another?',
#  'Is Google Nexus better than the other Android phones?',
#  'What does it mean when people say that psychopaths have a disregard for social norms? What does "disregard for social norms" mean?',
#  'How can I endorse a check?',
#  'Which are some good romantic novels?',
#  'When do boys and girls start masturbation? What is the "healthy" age for it? And until what age they are biologically entitled to do? What are the factors here, and how do these factors differ in men vs. women?',
#  'Is my voice deep if a voice recorder records it as deep?',
#  'What are the best TED Talks by youth?',
#  'Is driveredtogo.com legit or a scam?',
#  'How do you think about Chinese food?',
#  'Has India been succesful to divert world attention from Indian army atrocities comitted in Kashmir to a fake "surgical strike"?',
#  'How much does it cost to build custom Facebook pages for business? What are the going rates you are seeing?',
#  'Why is chemistry so boring?',
#  'What is meant by Rice puller?',
#  'Is it possible to get pregnant before your regular period?',
#  'What is the best shampoo for thick hair?',
#  'Why are deep neural networks so bad with sparse data?',
#  'Do people still remember the Movie Water World?',
#  'From which year should MBBS students start preparing for USMLE?',
#  'How can I get a list of rich people who are willing to give to families that need help?',
#  'How do you eat salad?',
#  'How much electricity is enough for 250 watt and 400 watt bulb to run for one hour?',
#  'How will banning of notes affect the huge amounts of black money is Swiss banks and tax havens?',
#  'My face always looks sleepy. What can I do to look fresh and active?',
#  'Would a religious Catholic or Muslim face more discrimination in Paris?',
#  'What are stimulant-related disorders?',
#  'How legit is thedartmouth.com?',
#  'Where can I get ethnic Bengali products?',
#  'What will be the impacts of rooting out 500 and 1000rs notes on Indian economy?',
#  'What is the difference between digital and analog?',
#  "What are Hillary Clinton's plans on relations with India?",
#  'What is friction force? What are some examples?',
#  'Have you ever been crazy in love?',
#  'What is the difference between north Indian weddings and south Indian weddings?',
#  'What is the future of the Go programming language?',
#  'How does a celestial object bend space?',
#  "What's the relationship between antimatter and dark matter?",
#  'How does the average Australian taxpayer feel about the millions of dollars going into refugee processing centers in Nauru and Manus island?',
#  'How many users does SoundHound have?',
#  'What is data science and how to become a data scientist?',
#  'How long does it take for HPCL to announce interview result of GAE? Is they announce by website or mail.',
#  'What is the worst thing that you did in your life?',
#  "Why isn't infinity equal infinity?",
#  'What year did airlines cease giving out playing cards?',
#  'What are the qualities of a good mother?',
#  'What do the molecular orbitals of cyanide look like, compared with those of carbon monoxide?',
#  'What is the principle of the carbon lamp? Why can carbon filament have light?',
#  'What happens to the dollar bills if you accidentally leave them in your clothes as your clothes end up going into the washing machine?',
#  'Importance of evaporator?',
#  'How do I live a simple life?',
#  'What should I daily do to become a good speaker if I am at level 0?',
#  'How do I reset my gmail password with new cellphone?',
#  'If you were allowed to ask only one question on Quora, what would it have been?',
#  'How does it feel to be in an incestuous relationship with first blood relatives or siblings? How does it begin?',
#  'Why are people in South Carolina such terrible drivers?',
#  'Which are the best green tea wholesalers?',
#  'How many branches are there in mechanical engineering?',
#  'What are the best websites to learn economics?',
#  "How much does Legalzoom's divorce services cost?",
#  'What does a good business plan consist of?',
#  'Where can I get gold filled pendants manufactured in Indonesia?',
#  'How does sodium bicarbonate react with acetic acid?',
#  'How close we are to see 3rd world war?',
#  'What is mucus made of? How does it affect your metabolism?',
#  'How did you discover masturbation?',
#  'Books: How long would it take to write and complete a book?',
#  'What are the methods to avoid pregnancy?',
#  'How do I make my non Bluetooth TV Bluetooth enabled?',
#  'I have cellulite on my legs which makes me look fat. How do I get rid of it?',
#  'What is the farthest object from earth visible with the naked eye?',
#  'Which one is more powerful? SpaceX Falcon Heavy or NASA SLS?',
#  'How do I undo bsnl recharge online with netbanking?',
#  'Is addiction really a disease?',
#  'Why does Quora seem like a good idea gone wrong?',
#  'How much can be saved for rs 2007 gold buying on RSorder for Last Man Standing beta 7.28-8.10?',
#  'What is the SBT PAN number?',
#  'Was Hillary Clinton too drunk to give a concession speech the same night of the election results?',
#  "Why haven't any other countries been to the Moon since the U.S. last did with Apollo 17?",
#  'In modern times, are fixed military positions a liability?',
#  'How do I add value to my life?',
#  'What does your Eureka 7 moment feel like to you?',
#  'Was Donald Trump ever in the military?',
#  'How can I get investors for my startup in India?',
#  'What is the best process to find products to private label?',
#  'When I feel depressed and hurt, I harm myself. How do I overcome this?',
#  'What type of spices go great with mashed potatoes?',
#  'Which is the best way to learn networking?',
#  'If I buy a laptop with DOS, what are all the things I have to do for installing Windows 8/8.1? After that which of all drivers should I install?',
#  'Which distribution of Linux is best for a new user on a Laptop?',
#  'What are the best gift for your girlfriend?',
#  'How do I study all day?',
#  'What is a Tokamak made of?',
#  'What is the intermediate value theorem? What are some examples?',
#  "Why doesn't Whatsapp have an Apple Watch app (yet)?",
#  'How does e-marketing companies such as freecharge and paytm  profit despite coupons they give out to customers for promotion ?',
#  'Is it true that honey is capable of changing your eye colour naturally?',
#  'What are the best kept secrets ever?',
#  'How does one cope with and eventually overcome Social Anxiety Disorder?',
#  'How can you determine the chemical formula for ammonium thiosulfate?',
#  'Why is racism often a double standard?',
#  'What is the best FILM you have ever seen?',
#  'How can I put games (Tetris, Snake, Maze, etc.) on my Casio Algebra FX 2.0 Plus calculator?',
#  'How can I prepare myself for my upcoming class 10th ICSE board examination?',
#  "If I follow a private profile on Instagram, will my follower be able to see it if they don't follow that person?",
#  'Is Scotland going to leave the UK?',
#  'How can I find a good monologue for an audition?',
#  'Can I chant Durga chalisa without taking a bath?',
#  'Will Hillary keep her promise to oppose TPP?',
#  'I am 22. I have never played any sport but now want to start playing tennis (not professionally). Is it too late for me to start?',
#  'If PM Modi wants to curb black money? Why was the new 2000 rupee note introduced?',
#  'How do Jesus convince his followers that he is the Messiah? When and how did Jesus realize that he is the Son of God and his mission on earth?',
#  'Can a hermaphrodite impregnate itself? If so, how?',
#  'How many bullets were fired on D-Day?',
#  'Is it normal that my girlfriend comments on my physical characteristics objectively, but gets mad when I do the same to her?',
#  'When I insert my micro memory SD card it displays the error as volume is not accessible. I have the images in it. How do I recover them?',
#  'Which countries are not in good terms with India other than Pakistan?',
#  'How do Pakistanis view Tarek Fatah who considers himself an Indian despite being a Pakistani?',
#  'How do I implement the atoi function used in C?',
#  'Is there a tool that can crawl your entire sitemap?',
#  'What\'s the difference between "for" and "to"?',
#  'What is the pan number of State Bank of Travancore?',
#  "I pay 10 lac rupees a year as income tax. Am I getting my money's worth?",
#  'What is your review of Narayana Junior College, NGIC, Nallakunta?',
#  'Which book should be referred for the NICMAR entrance examination?',
#  'Are you good at organizing time?',
#  'Is there a computer program that shows the time, weather, and news?',
#  'If a genie grants you three wishes, what would you wish for?',
#  'Can Delhi ever get rid if stray dogs?',
#  'How do you translate the Spanish word "que" to English?',
#  'Which is the best app development company in Miami?',
#  "Was there a Brahmin massacre in Calcutta after Gandhi's assassination?",
#  'Do you believe every person has a soul mate?',
#  'I forgot my password in my BSNL WiFi modem. How can I reset it?',
#  'How does imagery help a reader?',
#  'Who was Sanjay in Mahabharat and how did he get the power to oversee the entire war?',
#  'Is it a good idea to buy a used car from a car rental agency?',
#  "Is it actually plausible that Putin's net worth is over $200 billion?",
#  'What is the easiest way to hack Facebook account?',
#  'How do I get rid of my lower belly?',
#  'Why does anything exist?',
#  'How could we improve education in Thailand?',
#  'What is the PAN number of TJSB Bank?',
#  'How do I delete thousands of old unread emails in outlook.com?',
#  'To what extent does Demonetization help the inflation of a country?',
#  'What is the smartest piece of code you have ever written/seen?',
#  'What are the advantages and disadvantages of non SI units?',
#  'Were the ancient gods real life aliens?',
#  'How do I prepare for the IAS 2017?',
#  'I want to be a top class programmer in my life. How many problems should I solve each day to achieve my goal?',
#  'What is the way to make a girl fall in love with you?',
#  'Why do I randomly get up and walk around?',
#  'What makes people go crazy after undergoing anesthesia to get their wisdom teeth pulled?',
#  'How do you bring traffic to your website?',
#  'Who would win in a Twitter war, NATO, Russia or China?',
#  'How can an hour of cardio a day improve your health?',
#  'Is male circumcision compulsory in Islam?',
#  'Which are the best place to Holiday in India?',
#  "How did the writers of Seinfeld come up with Kramer's first name, Cosmo?",
#  'Is it spelled "co-operative" or "cooperative"?',
#  'Should Turkey join the China-led Asian infrastructure investment bank (AIIB)?',
#  'How do Ayn Rand objectivists suggest that existential threats to mankind be dealt with?',
#  'What do Chinese people think about Nepal and Nepalese?',
#  'What are the best business ideas for rural India?',
#  'Will doing push-ups help me build muscle?',
#  'World top online selling sites to sell Indian wooden handicrafts and Novelties/nauticals from India?',
#  'Moon nearest to earth on 13 dec 2016@ 04:20 AM?',
#  'What is surgical strike by India?',
#  "What is the most selfless act you've ever witnessed?",
#  'Why is the concept "live one day at a time" so hard to grasp?',
#  'Why did McCullum not wait for T20 WC to retire? Why did he retire at 34 with 2-3 years of cricket still left in him?',
#  'What is sea buckthorn?',
#  'Why do people ask questions here in Quora instead of just googling?',
#  'Can fish still die in freezing water?',
#  "What is the correct way to pronounce 'tree'?",
#  'What are the most amazing psychological hacks?',
#  'How do I explain to people why I deleted my social media accounts?',
#  "Why don't people like Nickelback?",
#  'How do you determines whether a molecule is sterically hindered, or not?',
#  'What is one thing you caught your parents doing that you wish you had never seen?',
#  'Why are people so obsessed with GoPro cameras?',
#  'Phd: How do you protect your dissertation ideas?',
#  'How do I change my registered mobile number for SBI Visa Debit Card?',
#  'How does Quora intend to generate revenue?',
#  'Is it too late to learn Ruby on Rails in 2016? Have I missed the train? Will I be hirable?',
#  'How might humans look if we grew up on a planet with half the gravity of earth?',
#  'Why did Osama bin Laden started hating America after the Soviet War in Afghanistan?',
#  'What is the difference between knowledge, intelligence and wisdom?',
#  'Did the Ancient Phoenicians (Canaanites) discover the Americas?',
#  'I want a better SOP (statement of purpose) to file my canadian student visa. I want to express myself in a better way and my interest in program?',
#  'Is traveller.com a scam?',
#  'Why is India purchasing the Rafale rather than the F15 Eagle or its variants which is at par with the Rafale & also much less in its cost?',
#  'How do I know if I have a 64 bit processor running a 32 bit OS?',
#  'What is the best place in NCR to get car accessories?',
#  'How can a guy protect himself from girls lying about that if they got pregnant, then they would get an abortion, and then suddenly she decides to have the baby?',
#  'How can I increase the traffic on my website? Jeenkart.com',
#  'Where are the best female escorts in Mumbai?',
#  'What makes some people more popular than others?',
#  'What are the best apps for editing vines?',
#  "In the book/movie 'The Big Short', how did Greg Lippmann/Jared Venett profit off the crisis?",
#  'How to stop colleagues from bullying me?',
#  'How do I stop my Labrador/Pug mix from humping my pillows?',
#  'Is it true that in five or ten years most men will have a big penis due to penis transplants and 3D printing?',
#  'Have you ever had a same-sex encounter?',
#  'What is a "non-euclidean geometry"?',
#  'Which laptop is best in the range of 50-60k for a engineering student?',
#  'What is the tech stack behind theintercept.com?',
#  'Who was the last U.S. President to receive an endorsement from the Ku Klux Klan?',
#  'What was your favorite movie of the 1980s?',
#  'What is a consecutive calendar day and how is it related with the Thai lunar calendar?',
#  'Do you require landline connection for hathway internet connection?',
#  'How do you clean smegma?',
#  'Will it be possible to earn a stable income form Free Spins?',
#  'I drink 1 litre of milk every day. Is it dangerous in some way?',
#  'My Guess wrist watch may be running out of battery? Shall I buy a new one of Guess or buy one from the local parts outlet ?',
#  'What is Architecture about?',
#  'What are some Metallica love songs?',
#  'Is the sentence correct? "I\'ll make sure he\'ll pay the remaining amount"?',
#  'How can I Self Publish Book in Malta?',
#  'Why should someone do MBA?',
#  'What universities does Dexcom recruit new grads from? What majors are they looking for?',
#  'If I watch a video on YouTube, does the owner of the video see the user who has watched it?',
#  'Why stray dogs bark at rag pickers?',
#  'What is the recipe for success that most entrepreneurs use?',
#  'Who is considered as the worst actor/actress in Indian film industry and why?',
#  'What is the fastest way to make $5000?',
#  "Where can I get the C-CAT and CDAC entrance exam previous year's question papers?",
#  'Is World War III on its way right now?',
#  'What are the problems faced by Indian students in the USA?',
#  'How can I make friends in middle school?',
#  'What is general semantics?',
#  'After how many days can a person re-enter the US on a B2 visitor visa after staying there for 2 months?',
#  'In campus placements do they see the 12th class marks as I have got 58% in ICSE?',
#  'How can I earn money easily online?',
#  "How did the Army guy do the magic trick where he disappeared the girl on America's Got Talent? (June 22, 2010)",
#  'What are some things new employees should know going into their first day at Aspen Insurance?',
#  'What is the best way to freeze fried rice?',
#  'What is the best output setting setting for premiere pro?',
#  'Is packaged pasteurized milk safe to consume without boiling?',
#  'For older parents (over 40) with kids between 3-6, how do you manage your exhaustion?',
#  'What does it feel like to go through the educational system in France?',
#  'What are the signs and symptoms of borderline personality disorder?',
#  'Are property prices in Pune finally going down?',
#  "What are the main differences between a bachelor's and a graduate degree in nutrition in terms of career prospects?",
#  'Do ivy leagues look at final subject   grade or mid term subject grade ?',
#  'Which is the best source for Buddhist Political Thought for PSIR optional in UPSC?',
#  'How can microeconomics affect macroeconomics?',
#  "What's Squarespace bookings widget do you recommend?",
#  'Les Misérables (2012 movie): What did Javert see in Valjean to get him obsessed?',
#  'Which is the best mosquito repeller?',
#  'How can I get my mind to work under pressure?',
#  'Does a person need to have French citizenship or legal residency join the French Foreign Legion?',
#  'How can I apply for an Indian Voter ID duplicate online? Odisha',
#  'What is string theory and what is its use?',
#  'Could cars run on water?',
#  'Did anybody send their teenager daughter to a therapeutic boarding school?',
#  'Do anonymous Quora questions get more views?',
#  'What are some of the best ways to start a conversation with a girl?',
#  "How do I tell my parents I want to leave the college I'm in right now?",
#  "How does the introduction of new 500 and 2000 denomination currency and stopping old 500 & 1000 denomination currency help/ affect India's economy?",
#  'How do I exchange foreign currency to Indian rupees?',
#  "What's your favorite song right now?",
#  'Why are some people so loud on the phone?',
#  "Why do I love my ex so much and can't let him go but still not happy, even though he left me and came back after 2 weeks?",
#  'What are some mind-blowing facts about Steve Jobs?',
#  'Is there really a plot by the Illuminati totake over the world?',
#  'Why is Lord Shiva under the feet of Devi Kaali, after Devi kaali  killed the Asura Raktabija?',
#  'How do restaurants in NYC deal with dine and dash situations?',
#  'Do shrinks slack, and if so, how can one prevent shrinks from slacking?',
#  'Is a UV light the same as a black light?',
#  'What does "encompass" mean? What is an example of a sentence using that word?',
#  'Could you buy two airplane tickets if you want a free seat next to you?',
#  'Which is the most eminent letter of English alphabet?',
#  'What are some major social faux pas to avoid when visiting Syria?',
#  'Is university really worth it?',
#  'What should be the question asked in a fresher party?',
#  'How should I plan a trip of few days to Goa?',
#  'Why do some adults like to bully others?',
#  'What\'s the meaning of "Live every day as if it were your last"?',
#  'What are some major technical breakthroughs in recent video games?',
#  'What advice Pakistanis living in Pakistan will give to overseas Pakistanis?',
#  'What backpack was used by Oliver Queen to break out John Diggle from prison in Arrow Season 5?',
#  "What are some of Spain's best kept secrets?",
#  'Do you think men and women can be "just friends" each other?',
#  'What is a good Haskell tutorial that offers learning by small task programming?',
#  "Why aren't jaguars used in animal shows as often as lions and tigers?",
#  'How do I become an expert in VR?',
#  'What is your review of Graphiq?',
#  'Do birds learn to fly?',
#  'How is the alcohol in beer/wine/others different from other types of alcohol?',
#  'Should I try cocaine?',
#  'Do employees at QTS Realty Trust have a good work-life balance? Does this differ across positions and departments?',
#  "What's your favorite TV show and why?",
#  'Do narcissists obey when you tell them to never speak to you again?',
#  'Do girls see boys as boys do?',
#  'What are the chances of getting back together with a girl who has only good memories of you and you were trying to be nice all time?',
#  "Why can't Chinese people revolt against their government for a democratic regime?",
#  'How do you write an application for a leave of absence?',
#  "I don't have any friends and I feel lonely, what should I do?",
#  'If Donald Trump loses the general election, will he attempt to seize power by force claiming the election was fraudulent?',
#  'What does Obama think about black people being killed by cops?',
#  "Why isn't the state Odisha highlighted in the national media as other states?",
#  'Why do some call the Permanent Court of Arbitration a UN-backed tribunal?',
#  'What are some amazing balancing tricks using science?',
#  'What is the difference between a data model and database schema?',
#  'How do I control emotions..Like Heart Breaking emotions?',
#  'What is the most polite way to refer to black people?',
#  'Who is the founder of yiest?',
#  'Can a war between India and Pakistan eventually lead to a Third World War?',
#  'Between Trump and Clinton who will win US presidential election?',
#  'Is it possible to implement a USSD App without engaging a TELCO?',
#  'What is the average annual salary of an Uber/Meru/Ola cab driver in mumbai?',
#  'How do airlines currently price their tickets?',
#  'What is the current state of Gay rights in India? Is it legal or illegal or legal in Delhi only?',
#  'I would like to buy a portable C.B. Radio with a scanner in case of emergency. What should I buy for my family?',
#  'How can I improve my English vocabulary and writing skills?',
#  'What are the copyright laws and intellectual property issues associated with an app like Pocket that you can save articles to read later from around the web?',
#  'What are some examples of pathogens?',
#  'What is an Eigen vector? What relation does it have to basis vectors?',
#  'Can we control our dreams? Can we dream what we wanna dream about?',
#  'Should I wear a helmet while riding a Razor scooter?',
#  "Are people these days aware of the Democratic Party's bad history, or do they just not care?",
#  'Can I withdraw PF with UAN?',
#  'How dark does the dark web get?',
#  'What are the advantages of polyandry?',
#  'What majors and minors do I need for photography?',
#  'How much does it cost to buy an island?',
#  'What does it feel like to be attractive and desired by many?',
#  "I'm gay and my best friend is straight. He taunts me with his body knowing I'm attracted to him. I've never voiced my displeasure. How do I get it to stop?",
#  'How does the brain create consciousness?',
#  'How can I promote my blog anonymously?',
#  'Was a dinosaur a reptile really?',
#  'Is age really just a number?',
#  'How do I kill rats?',
#  'Why do people use credit cards instead of debit cards, saving money for things and living within their means?',
#  'What is the best way to study biology fast?',
#  'What are the career options available for an electrical engineering graduate?',
#  'What are the latest IT trends?',
#  'Is it wise to upgrade to Windows 10 now?',
#  'What are some traits of Hamlet?',
#  'What action should a person do to survive in a free falling lift?',
#  'How do you choose an auto repair shop?',
#  'Is it beneficial for a 19 year old to drink green tea?',
#  'What was the population of Nebraska by year from 1850-present?',
#  'How can I make a girl fall in love?',
#  'What kind of online business can I start with 500$ per month?',
#  'Development Practice: Have you ever worked on a successful water project in urban Africa? What made it successful?',
#  'How many active users does LoseIt have?',
#  "How come I can't execute Cross origin requests with XMLHttpRequest (accessing a file from a remote domain) in my JavaScript file via the browser, but when I execute the same JavaScript file in node.js it works?",
#  'My employer is not paying my salary and not gave written offer letter till now. What should I do? How can i go legally?',
#  'Who are some of the best underrated actors in Bollywood?',
#  "I asked a friend who they like and he said someone, he won't tell me who tho, my friends think that he might like me because he won't tell who it is?",
#  'How do you fix a zipper on jeans?',
#  'How is Fordham University’s analytics program?',
#  'What are police codes? What is the meaning of the police code 1055?',
#  'How do you cook brisket in the oven?',
#  'What is the smartest thing you have seen somebody do?',
#  'What do you think about the first presidential debate between Hillary and Trump?',
#  'What concessions should America make to placate Russia and end hostilities between the two countries?',
#  'Why is my Alexa ranking decreasing day by day on my website?',
#  'Is happy ending massage legal in India?',
#  "How realistic is Elon Musk's plan to colonise Mars?",
#  'How do I decorate a bedroom with a 2010 theme?',
#  'Was Fidel Castro a dictator or a hero?',
#  'What experiences have you had to restore your faith in humanity?',
#  'How do I read and make notes from The Hindu and the Indian Express for RBI Assistant and other banking Exams?',
#  'How do you flirt through text message?',
#  'Which company is good for internship if I am a B.Tech 3rd year student from the CSE stream? How can I apply for the government companies?',
#  'What is servlet?',
#  'Why do many men have the perception that women are attracted to jerks? I have never dated a jerk in my entire life.',
#  'How do double bonds and triple bonds compare and contrast?',
#  'Why is autism becoming more common?',
#  'What would happen if you jump off a cruise ship?',
#  "How can I write a good CV if I don't have any working experience?",
#  'How can I ask my crush out?',
#  'Age: Is there anyone aged between 30 to 40 who has never had a proper relationship before?',
#  'Should I watch Game of Thrones before I read the books?',
#  "I'm planning to start up my own fashion boutique in Delhi. Where should I purchase my wholesale clothing items from?",
#  'Should boys of age 16,17 and 15 years wear sleeveless in public? Why or why not?',
#  'What are you guys doing after graduating Btech in ECE?',
#  "Jimmy Page vs David Gilmour vs Slash. Who's the best?",
#  'Who would win in a fight between Magneto and Batman?',
#  'Would you follow yourself on Quora?',
#  'What makes yawning contagious?',
#  "What is Kanye West's best song, in terms of samples and production?",
#  'What is the advantage of polarized sunglasses?',
#  'How does law of attraction work?',
#  'Is IBM dead?',
#  'What are some social class markers in India?',
#  "Why don't people learn from their mistakes?",
#  'How is memory related with intuition?',
#  "Do you remember movies that you didn't like?",
#  'Is the rapper Eminem\'s fame decreasing due to his new, fast rapping style like in his latest album, "Shady XV"?',
#  'What is the equation for anaerobic respiration in yeast?',
#  'Is taking a drop in IIT JEE exam a good decision?',
#  'What are the benefits and negatives of India’s caste system?',
#  'What is the state of smartphone business in India?',
#  'How can I stop getting irritated?',
#  'What are some tips for getting high scores in Imbroglio (iOS game)?',
#  "I'm looking for a NYC freelancer to build a ecommerce site using shopify or squarespace. How do I go about finding someone who specializes in these tools?",
#  'What are some examples in life of when less is more?',
#  'Are atheists more likely to be vegetarians?',
#  'What is the best way to ask a former boss if they would hire you again when you might have not given your absolute best the first time?',
#  'Is Barcelona full of tourists in the second half of September?',
#  'Which comes out first the hen or the egg?',
#  'Can you report a rape after 3 years in India? Is there anything that can be done? I know that I should have reported it when it happened but I was scared of getting blamed. Is there anyway I can get him punished/sentenced for this crime?',
#  "What are Donald Trump's qualifications for President?",
#  'If vitamin pills do not get absorbed by the human body, as many say, why do doctors prescribe vitamin pills to pregnant women?',
#  'Is there any possibility that reservation on the basis of caste will end in India in future?',
#  'Can another black hole exist in a black hole?',
#  'What will be the future in mobile technology?',
#  'Why did MS Dhoni steps down as captain of India limited overs side?',
#  'What the best way to improve English?',
#  'What are some good liquors that would you mix with tequila to make it less stingy?',
#  'What is the most Photoshopped photo/image of all time?',
#  'Taking meth through the rectal, is it a better high?',
#  'How do I deal with dominating people?',
#  'What are the best German beers sold in U.S.A.?',
#  'What is so great about Sachin Tendulkar?',
#  'How do I become mature?',
#  'What are some unexpected things first-time visitors to Iran notice?',
#  'What were the good qualities Adolf Hitler possessed as a political leader?',
#  'How can I stop having paralyzing fear about the future and outliving all my relatives and dying alone without enough money to live off of? See comment',
#  'How do I read data like passwords or messages sent over my network using Kali Linux?',
#  'How can I teach my child to be truthful?',
#  "I'm nearly 20 and feel like a failure in my whole family, I don't know what I want to do yet?",
#  'What is the deal with Marshawn Lynch and Skittles?',
#  'Would there be any difference if the U.S.A. had a prime minister instead of a president?',
#  'What are some good tips while learning piano?',
#  'What is the difference between instrumental desires and non-instrumental desires?',
#  "What kind of job can you get with a bachelor's in finance?",
#  'What are the best ex-Mormon forums and why?',
#  'Why did Voldemort use Nagini to kill Snape instead of Avada Kedavra?',
#  'What is the way to communicate gambling halls owners?',
#  'Does Star Wars: The Force Awakens have a darker tone than the other Star Wars movies?',
#  'How can a mosquito fly inside a moving car?',
#  'If civilization was subdivided into equally sized nations based on college degree or technical field, what would (1, some, or all) be like?',
#  "What's the difference between commercial banking and retail banking?",
#  'If someone blocked me on WhatsApp then how can I see her last seen and profile picture on WhatsApp?',
#  "What's the most frustrating thing about being you?",
#  "A majority of the torrent sites have been blocked in India. Which torrent site can I get my movies from? P.S. I'm a bachelor (not working yet), can't afford to buy original dvd's.",
#  'How do you know if a Scorpio man really likes you or hates you deeply?',
#  'Did anyone ever lost a mobile in your home when it is turned off? Did you find it ? How?',
#  'How were the Pyramids of Giza built?',
#  'How many Ibps clerical attempts are there for general category?',
#  'What are the best ways to explain someone how much you love them?',
#  "What was the Founding Fathers' real hair like?",
#  'What is meant by cold email?',
#  'What are the highest paying jobs in the U.S?',
#  'Can I sue the government for noise pollution? Whenever they run fighter jets down my neighborhood and setting off car alarms?',
#  'What is the best food to eat when you are down with fever?',
#  'Are we overdue for a world war?',
#  'What are some Clash of Clans clan names?',
#  'How do persons with HFA (Aspergers) view sex?',
#  'What is the responsibility of a boater to protect the shoreline?',
#  'What are reasonable restrictions and savings clauses in franchise disclosure documents?',
#  'I want to quit my govt bank job and study for UPPSC upper subordinate?',
#  'How do I improve my relationship with my wife?',
#  'Is WWE Wrestling acted?',
#  'What percentage of people born in 1958 are still alive?',
#  "How are/were the stations' codes decided on Indian Railways?",
#  'What is the diet of a woodlouse?',
#  'How do I stop my dog from peeing on my bed?',
#  'What is the function of the mitochondria in a plant cell?',
#  'One of my friend submitted fake IT proofs to save tax. If he was found by the IT department, what will be the consequences?',
#  'What are the main causes of depression?',
#  'What is the scope after doing Mtech in automobile engineering from IITs in India?',
#  'Is it possible to lose weight without going to the gym?',
#  'Employee Screening: When you drink water excessively, is your first urination diluted? ',
#  'I have a HTML JavaScript in 30 webpages, I change/update it daily, want to update them in a single click without going to those 30 pages. Any help?',
#  'Why doctors are not considered as humans?',
#  'How do I check my UAN number?',
#  'Is there any difference between the student studying in a government law college and a private law college?',
#  'What is the best way to a positive life?',
#  'How is Water, Smart World & Communication IC to work for Girls as a GET in LNT ECC?',
#  'How much should I study for the SAT?',
#  'Is modi government doing anything to remove caste based reservation?',
#  'How much negative charge has been removed from a positively charged electroscope if it has a charge of 7.5x10-11C?',
#  'What is #define in C?',
#  'What is difference between an asset management company and a mutual fund company?',
#  'Whos the best rock band?',
#  'Could Michelle Obama run for president if she wanted to?',
#  'What are red blood cells?',
#  'What is your review of Stain Removal?',
#  "What were Mother Teresa's contribution to society?",
#  'Do I need an EIN if I want to import in the US being a non US resident?',
#  'How will the ban of Rs 500 and Rs 1000 notes affect Pakistan?',
#  'Can I change my current email address? How?',
#  "What's the reason behind such kind of offers?",
#  'How do you hypnotize someone?',
#  'What is the name of the girl that appeared in Shawn Mendes\' music video for the song "Treat you better"?',
#  'What\'s with the new "Sorry! Page not found" page in Flipkart? Why can\'t I go back to the previous page after clicking back from this page?',
#  'Why does it hurt when we bite our tongue unintentionally than it does intentionally?',
#  'Where and how can I find a life coach or mentor?',
#  'What is the best and quickest way to download the whole playlist of videos from YouTube all at once?',
#  'How can you calculate volume, mass and density?',
#  'Who is richest person on Quora?',
#  'Which are the best applockers?',
#  'Where do we have to stay while pursuing MS in U.S.A?As far as I know there are no universities which provide hostel facilities',
#  'What does it mean if a guy says that another guy is lucky to go on a date with you?',
#  'Does this post have any truth to it?',
#  'What are some online jobs which can be done from home?',
#  'Is a franchise a good idea to start up a business?',
#  'Which smart phone is best in 2016?',
#  'Why is boxing called the sweet science?',
#  'Which is the best place in mumbai, near borivali, for a candle light dinner?',
#  'How do I change the WiFi password on a router?',
#  'Which laptop is best under 40000 INR?',
#  'What is the difference between PayScale salary and basic salary?',
#  'What are the most secretive places on earth?',
#  'Is annotary.com dead for good?',
#  'What are the sexiest things someone has said to you?',
#  'How can I become more resourceful?',
#  "Why do men like to wear women's panties?",
#  'Why is Prom ironically popular in Japan?',
#  'How long to use 3m 9000in face mask?',
#  'How do you speak in front of large groups of people?',
#  'How do I start learning new things by self?',
#  'Is Taurus the best sign? Are we like the knights of the zodiac?',
#  'How long does it take you to die if you drink alcohol everyday?',
#  'How do I use 360 video in website?',
#  "What was it like to grow up as a teenager in the 1980's?",
#  'How do I write a post Quora?',
#  'How do I get my friend to be my roommate?',
#  'What is the different on market research between focus discuss group and one-one indepth interview?',
#  'How many wives or consorts did genghis khan had?',
#  'What is the most painful thing you have ever experienced?',
#  "How do you make sure your Quora activity isn't displayed on your Facebook posts?",
#  'What will Hillary Clinton do now?',
#  'What are your views on Supreme Court decision of must National Anthem before movies?',
#  '"If you don\'t leave, I will in life and death." How do native English speakers comprehend this sentence? Is it a proverb?',
#  'Where can I get the best denim jeans & casual shirts in Bangalore at wholesale prices?',
#  'Am I allowed to take spices in my checked luggage? What is the maximum amount I can take?',
#  'How does it feel to be a successful fashion model?',
#  "What's the best way to find investors for a restaurant?",
#  'What notice is required to file returns under Sec 234?',
#  'What are some recommended TV series if I like Game of Thrones and Suits?',
#  'What are the functions of prefrontal area of the brain?',
#  'What are the differences between a Brahmin and a non-Brahmin, asides their food habits?',
#  'What should I do if I have purple fingernails?',
#  'Which are the best coaching centers for CSAT in Delhi?',
#  'What is the best way to clean clear aligners?',
#  'Is the French Rafale aircraft better than the Eurofighter Typhoon and the SAAB Gripen?',
#  'Can I learn car driving without having a car? (India)',
#  'What makes a successful conference workshop?',
#  'Is there a ghost in the world?',
#  'How do startup IT/software companies in India ensure that job offers made to laterals (experienced) actually convert to joining?',
#  'What is the specific heat of plastic? How is this determined?',
#  'What is the scope of mechanical engineering in the USA, the UK and Australia?',
#  'How do I prevent myself from dozing off during lectures?',
#  'How can I update my pan card details without visiting the bank?',
#  'Which type of project does society need?',
#  'How can you know yourself better? By interacting people or by spend some time alone and think.',
#  'What are horizontal stressors and how do they differ from vertical stressors?',
#  'Can I use a Bluetooth 4.0 headset on my Bluetooth 3.0 Android smartphone?',
#  'What are examples of zygote fungi? How are they different from other fungi?',
#  'MK ULTRA may not be an active program, however what would stop a group of people in positions of power abusing this concept for profit?',
#  'Could there have been any humans before Adam?',
#  'Is the salary of a physics/chemistry major more than that of a mechanical engineer?',
#  'How do I replied betterly on bday wishes as a bday boy?',
#  'Why do doctors flick the needle before giving injections?',
#  'Why is wasting time so important?',
#  'What are some things to look for when buying a house or condo built before 1950?',
#  'When a man becomes a President, his wife is called first lady. If a woman is President, what is her husband called?',
#  'On what basis are the top writers on Quora selected?',
#  'How can I gain weight fast by exercise?',
#  'Who is the highest paid player in the WNBA?',
#  'Is Dell Alienware Graphics Amplifier compatible with Bootcamp Windows 10 for running high spec games like Black Desert or other high graphics?',
#  'Who is the most beautiful woman on Game of Thrones?',
#  'How do you paint your rims black?',
#  'How do I start preparation for a law entrance exam? What subjects should I study?',
#  'How would Authoritarians act to gain control or influence over the Internet, given the ICANN transfer from U.S. Custody?',
#  'How can I build a laptop on my own?',
#  'How important do US citizens think the Philippines are as an ally?',
#  'Where can I get a wide variety of wedding dresses in Gold Coast?',
#  'How can I magnetize chalk paint?',
#  'What is Worldpackers.com exactly?',
#  'What is the mechanism behind the working of a ballpoint pen?',
#  'Why do people feel lonely even though they are with people?',
#  "Can astronauts choose to come back to earth if they're really sick or some other reason?",
#  'What is the smallest sailboat to sail nonstop around the world?',
#  'How is Jobr doing?',
#  'How can I become a charismatic person?',
#  'What are some examples of mixtures and compounds?',
#  'What do you plan on doing with the Syrian Refugees crisis?',
#  'Is November blackout fake?',
#  'Why do I sneeze when I look upwards at the sun?',
#  'How do I file a complaint against a carrier network?',
#  "Why won't IFTTT link to my tumblr account?",
#  'Islam: Is nationalism un-Islamic?',
#  'What is it like to intern at Cisco in 2014?',
#  'What is your favourite family Christmas tradition?',
#  'Is there any tools to compare actual given specification with screenshot taken from iphone5s in windows OS?',
#  'What would a guy think if he sees a girl looking at him?',
#  'How real is the show Undercover Boss?',
#  'What are the best brain teasers?',
#  "Why isn't India among the great tourist destinations despite her diversity?",
#  'How can I find where an instagram page was created from?',
#  'How do I find my lost mobile using IMEI?',
#  'Daniel Ek: What is the next step for spotify? Which key areas of music industry is Spotify looking to make a mark in future?',
#  'How do I get more views in YouTube?',
#  'What are some of the most common examples of confusing correlation and causality?',
#  'What is the worlds favourite colour?',
#  'What does it mean when you ring a mobile and you get this line is busy?',
#  'What are the best web hosting providers?',
#  'Which Neko Atsume remodel should I get?',
#  'How can we make Pakistan great again with the help of Donald Trump and China?',
#  'Why did Banda Singh Bahadur surrender before Mughals? Should we call him a weak General or warrior who opted surrendering over fight and die?',
#  'Can I install state of the art electric wardrobes for my room?',
#  'What was your first question asked on Quora?',
#  'How do you play dungeons and dragons?',
#  'How can one change or choose his personality?',
#  'Why did Jimmy Page start playing with a violin bow?',
#  'How do I insert a sigma symbol into a word document?',
#  'Why is PK better than Oh My God?',
#  'What is it like to be raised by an Indian mother?',
#  'What is the future scope for a system engineer?',
#  'What is the biggest secret you have been told?',
#  'Is the Macbook pro 2016 overpriced?',
#  'How did Oliver Wendell Holmes show nationalism?',
#  'What are the best books on persuasion and debate?',
#  'Which are the best books to learn C++?',
#  'What are transition elements?',
#  'What is the life after death.?',
#  'I want to make a video of me step by step improving my life. What video editing tools would I need?',
#  'Where can you buy song lyrics?',
#  'How often do airline pilots use the HUD and what are its advantages?',
#  "Chinese Food: What is the origin of General Tso's chicken?",
#  'What are the similarities and differences between communism and imperialism?',
#  'Is not reading books a bad thing?',
#  'What is graphic design?',
#  'How do medical students take notes when studying?',
#  "How will the presidency effect Trump's ego?",
#  "If you can't lose fat and build muscle how do fat guys go through transformations and get ripped and buff?",
#  'Is Aakash kurukshetra better for medical preparations?',
#  'How safe is chiropractic care during pregnancy?',
#  'Why do bad things have to happen to good people?',
#  'What is the meaning of an authorised dealer?',
#  "What's the difference between AAdvantage million miler balance and the program to date miles in my American Airlines account? ",
#  'Why does time pass faster as you get older?',
#  'Why does breast cancer receive more attention than other forms of cancer?',
#  'Why do Australia, Canada, and New Zealand choose to retain the Queen of UK as their head of state? Any advantage? Is it in lieu of forming an alliance since most people are essentially  from same roots?',
#  'How did US recover from the financial crisis in 2008?',
#  'In a job interview, how do I explain leaving my last position because of a toxic work environment?',
#  'How do I see things as they are?',
#  'Pune Railway Station Cloak Room: where is it, charges, how is the service, any specific rule?',
#  'What degree should I do after MCA for further studies?',
#  'What is a composite primary key in a relational database?',
#  'What is another way of saying “-30m/s west”?',
#  'What are abstract data types?',
#  'Can 1.4 trillion dollars be attained through the internet?',
#  'Which is the best WordPress theme that can be installed in blogger.com?',
#  'How can I start preparing for GATE 2016 within 4 months?',
#  "What is the worst feeling in a teenager's life?",
#  'With a low percentile in CAT, can I crack XAT in one month?',
#  'Are there any questions on Quora about celebrities/politicians that have been answered by the very celebrity/politicians themselves?',
#  'What kind of cheese is Babybel?',
#  "I think the girl I love is also in love with me but she push me away like she don't want me I don't know how to know if she really likes me or is it just my mind telling me lies that she likes me too?",
#  'What is the difference between "buying", "purchasing" and "shopping"?',
#  'What should I do for my career growth?',
#  'Where can I study the SAT math curriculum?',
#  "Why can't electrons be frozen?",
#  'How do I learn about servers?',
#  'What are reasonable explanations for missing work?',
#  'What does it mean if a girl is taking hours or a day to reply to your text message but always replies?',
#  'In Return of the Jedi, what did Darth Vader die from?',
#  'What are the best books for beginners to understand and invest in the Indian share market?',
#  'What are the best poems of all time in English?',
#  'How can an individual learn about art?',
#  'Who is the better politician and why: Narendra Modi, Rahul Gandhi or Arvind Kejriwal?',
#  'Is a 1290 on the new (2015/16) PSAT a good score?',
#  'Are all things you can see in your living room produced in factories numourously?',
#  'Is the history of browsed videos in a YouTube mobile app saved in a public WiFi router?',
#  'Do Amazon.com orders often arrive earlier than the promised delivery date?',
#  'What is your favorite animal? Why?',
#  "What's the coolest feature you've seen in a motorcycle?",
#  "How do you diagnose the problem when a car won't start?",
#  'What is your favorite Halloween video?',
#  'What hotel in Palampur Hill-station would be safe for unmarried couples, without the harassment of police, hotel staff, and moral police?',
#  'Do guys think skinny girls are the most attractive?',
#  'What is the problem with Zee News channel?',
#  'What would be better for me (my academic score Secondary-72% and H.S 66%) so should I pursue C.A or go for M.B.A?',
#  'If someone blocked me, will they still get my text message?',
#  'How can I be a great lover?',
#  'Why does the sky appear blue? Why is the colour of the sky at the horizon different during sunrise and sunset?',
#  'What are some interesting facts about the ancient Vikings?',
#  'Do you make money by answering questions on Quora?',
#  'What is the most polite way to tell a coworker to stop chewing loudly when they eat?',
#  'What is the platform of the Alberta Party and if elected, how would they implement that platform? How does this compare to the Liberal Party?',
#  'Why are muslims throughout the world fighting each other? Just like that or are they being fooled?',
#  'How do I score an internship at a big law firm during my time at law school?',
#  'How does thermal pollution occur?',
#  'What can I do to become smarter?',
#  'What are the most annoying questions you see on Quora?',
#  'Does smoking marijuana make a person stupid?',
#  'Does Kung Fu really have its roots in India?',
#  'What is the best head cap or strap system if using HD-Ag/AgCL rings with holders?',
#  'My phone has been stolen. How do track my phone?',
#  'If an English-speaking person was to go back in time in England at what point would he or she no longer be able to understand the English language?',
#  'Why do professional tennis players blow on their racquet hand between points?',
# ...
#  'How do you display a list of all the tags in a Tumblr blog?',
#  'How do you become a dental hygienist?',
#  'Can Adidas Stan Smith Shoes be worn without socks?',
#  'Which are some of the best YouTube channels to subscribe for?',
#  'How do I determine my sexuality?',
#  'Are the data entry jobs found online genuine? Do they really pay?',
#  'What are some silliest questions asked on Quora?',
#  'On what scientific assumptions is the accuracy of carbon dating predicated?',
#  'I am like sleeping all the time. Having no attitudes or associations. Feeling like zombie, or stupid. Can you help me somehow?',
#  'What was the most-hyped TV show ever?',
#  "Does BJP e-cell downvote questions that they don't like on Quora?",
#  'Is biofibre hair transplant effective?',
#  'Suppose someone who is new on Quora got a crush over someone who has disabled his/her messages, what could be done in that odd situation then?',
#  'What is the difference between a service tax and a service charge?',
#  'What are your top 10 books of all time?',
#  'What is the best way to learn hacking in short time?',
#  'Why moving iron instruments work on AC and DC supply both but moving coil instruments work only in DC supply only ? ',
#  'Has Google Photos considered allowing people to auto-upload screenshots of photos on the computer? (kind of like what Gyazo and puush do)?',
#  'How is the anterior surface of cornea elliptical?',
#  'What are the chances of getting PhD position at the University of Alabama as an International Student?',
#  'How do I make video call in moto g4 plus?',
#  'Is it illegal to tear an Indian national flag?',
#  'What is the standard length for a shower curtain?',
#  'I have a high blood pressure and no chest pain or discomfort but my doctor has asked me undergo for an angiogram. Why is an angiogram necessary?',
#  'How do you play Dungeons and Dragons on Android?',
#  'What percentage of the display advertising market is captured by Demand Side Platforms?',
#  'What are the benefits of using Amazon S3?',
#  'Was Peter Tchaikovsky gay?',
#  "What can I do with my law degree if don't want to practice law?",
#  'How chose software testing or development as career?',
#  'Is the government hiding or harboring aliens?',
#  'Considering Peter pettigrew (wormtail) , Sirius black (padfoot), is James Potter an animagus (prongs)?',
#  'Why did the Indian government demonetize the current 500 and 1000 rupee notes and replace them with new notes?',
#  'What is the best part time job to work from home?',
#  "How do you know when you've written something good?",
#  'In what ways has the US mishandled its relationship with Russia in the post-Communist era?',
#  'How do you make vinegar?',
#  'What constitutes true beauty?',
#  'How can I take a screenshot in Microsoft Windows?',
#  'Why do we lie?',
#  'How do I convert SBI credit card payment to EMI?',
#  'How can I ask Quora a question about something that was marked "needs improvement?"?',
#  'Why is Martin Basinger critical about Japan?',
#  'Which are the coolest books that a biology student ought to have read at least once?',
#  'Is Maritime training institute, Powai a good college for doing GME?',
#  'What phone should I buy under Rs 15000?',
#  "Is underage drinking okay if it's in a private setting like at home and parents approve?",
#  'What are the pros and cons of an electric vs. acoustic violin and vice versa?',
#  'Why did Trump win the election?',
#  'What are the best books for C# for the beginner, intermediate, and advanced levels?',
#  'How should I Improve my English speaking to speak fluently in front of other can anyone suggested?',
#  'How do Canadians pronounce Quebec?',
#  'How can I find a workout partner for the San Francisco Bay Club?',
#  'How many cups are in a quart?',
#  'Does apple believe in planned obsolescence?',
#  'What can I do to run faster without running?',
#  'Was the decision by the Indian Government to demonetize 500 and 1000 notes right or is it a big scam?',
#  'Which topic should one do for a presentation of 5 minutes?',
#  'Which makes better headphones, Sennheiser, Skullcandy or JBL?',
#  'How would a psychopath react to a break in?',
#  'Why is the climate change denier movement so passionate?',
#  'How do you control which app the play/pause keys on a Mac apply to when iTunes and Spotify are both open?',
#  'Why do people like sad movies?',
#  'What does the Japanese word "naruto" mean?',
#  'Qustions and answers on solaris online trainings?',
#  'When did the World War end?',
#  'What must a thesis statement do?',
#  'I had signed an employment bond for certain years, but now I wish to leave the company. What is the best way of dealing with this situation?',
#  'Is a Black & Mild worse than a cigarette? Why?',
#  'How do you check for a counterfeit Indian Rupee Note?',
#  'Are there really any websites to chat with strangers?',
#  'What are the pros & cons of a democratic country?',
#  'What actually happens inside a massage parlour? What is a happy ending?',
#  'Who is the most tattooed football player?',
#  'What should I do if my dog keeps shaking his ears?',
#  'Which is the most useless website you have ever seen?',
#  'What is the evolutionary advantage for some noses being wide and flat and other noses being narrow and protruding?',
#  'Would it be a good or bad idea to buy broken phones, get them fixed and sell them for a profit?',
#  'Is Quora a social networking site?',
#  'Can you give me some tips for getting rid of my internet addiction?',
#  'Which is the best GATE coaching for CSE in indore?',
#  'Why is Robot Operating System (ROS) preferred?',
#  'Could a technologically advanced Borg gather all the water in the universe and destroy it and ensure that the universe can never make more?',
#  'What is the best piano tutorials for beginners?',
#  'What are the best exercises to correct back kyphosis?',
#  'How often should you be drinking green tea in a day?',
#  'Does anal sex hurt for men?',
#  'Which is the best free digital marketing course?',
#  'Can you envisage a situation in which two lines of force of an electrotastic field intersect? If not, why is this imposible?',
#  'If you knew your heart were to beat only 5,000,000 more times, what would you change and why?',
#  "What's a really good pizza recipe?",
#  'How do I access the ExtraTorrent website?',
#  'How much does Twitter pay a new grad software engineer?',
#  'Recommend some good books for building foundation for IIT in class 10?',
#  'Native SQL query?',
#  'How can I receive spam email?',
#  'What are the best books about machine learning?',
#  'What is the expected cutoff for KVPY SA 2016 -17?',
#  'Why do most American chain outlets fail in Singapore?',
#  'Is it hard to learn French?',
#  "What are some mind-blowing phones gadgets that exist that most people don't know about?",
#  'How do I transfer to a top US university from India?',
#  'What is the best natural food practice for my 50 days old Labrador puppy?',
#  'I am a part of the IBDP class of 2017. Can I still write an EE on Human Rights or does it have to be GloPo?',
#  'What is the best way to learn and understand C++ faster?',
#  'How long does it take you to finish the machine learning nanodegree on Udacity？',
#  'How similar is ancient Greek to modern Greek?',
#  'How do you find the median of two numbers?',
#  'Which are the best piano classes in Jaipur?',
#  'Can any Overwatch or TF2 fans review my Youtube Channel?',
#  'What is the best way to learn c programming from 0?',
#  'What is the best thing you ever bought?',
#  'What are some ways to increase .NET speed?',
#  'What is your review of Phobia (2016 movie)?',
#  'Is The Familiar of Zero season 2 available dubbed in English?',
#  'What are my chances of getting into top grad schools?',
#  'What is operations research?',
#  'What is the temperature of water at room temperature?',
#  'Why do Christians think that their god is the real god?',
#  'Is a regular M.Tech program at IIIT-B better than an integrated MS program at BITS Pilani?',
#  'Which is best cricketer all over?',
#  'What is the current carrying capacity a 100 kva distribution transformer?',
#  'How can I log in or delete my Instagram account?',
#  'What does the word "Bia/بیا" mean in Pashto?',
#  'Why do some men avoid answering questions?',
#  'Why is Hillary Clinton not in jail after all the allegations of crimes?',
#  'What is the full story of the haunting experience at Rest House which Jim Corbett has referred in Man-eaters of Kumaon?',
#  'How do you graph y=4x-1?',
#  'What is the difference between EMEM and DMEM media in animal cell culture?',
#  'What makes a Mercedes suspension unique? What does it have that others do not?',
#  'Is government law college good?',
#  'Why do people smoke?',
#  'Hey.. I work on my programming skill.I found it difficult, while I m good in math nd logical puzzle..how should I work on it?',
#  'What are the best vegan places in New York?',
#  'What are the best things to sell on eBay or Amazon to make money?',
#  'Does the sentence, "I expect to be disappointed," make sense?',
#  'How do I get started in the cyber security industry?',
#  'How do I prepare for bank exams in quants?',
#  "This girl was touching me comfortably. But, when I touched her in return, she looked uncomfortable &/ backing off. What's going on? What did I miss?",
#  'How do I start preparing for civil services?',
#  "Is it foolish to use public Wi-Fi if you don't truly need it?",
#  'Where can I get best digital technology on photo booth hire services in Sydney?',
#  "Why aren't there solar-powered cars?",
#  'Is age just a number as both parties are of legal age?',
#  'How I can do well in programming contests?',
#  'What do people do on their iPhone the most?',
#  'My penis is tiny, should I just stop having sex?',
#  'What do you think will happen to Star Wars after episode IX?',
#  'How can I become a better designer?',
#  'Which is the best headphone under Rs. 2000?',
#  'How do I know which memory mapping strategies are used in my computer?',
#  'On Instagram, when your are looking at someone else posts, why does it sometimes show the name of certain people you follow and then sometimes doesnt?',
#  'What is a procedural programming language?',
#  'Why is chromatin important in cancer?',
#  'What are the best business ideas in India to start with Rs.5 lakh?',
#  'Which is the best framework I should use in Python web app development?',
#  'What does it mean by isolated system?',
#  'What is the cause of tumors on the forehead?',
#  'Are there virus free porn sites?',
#  'Did time exist before the Big Bang?',
#  'Theism: What is the most convincing argument to become a theist?',
#  'What is the India of your dreams?',
#  'How can I get prepared for the IBM P2065-036 exam?',
#  'Can I order a new shoe from a cordwainer or cobbler still, if so how and where?',
#  'Why does time slow down when moving near the speed of light but...?',
#  "Why is my Samsung Galaxy S3's camara failing? How can I fix it?",
#  'Which is your biggest fear?',
#  'What are pharmacological ways to overcome a fear of flying?',
#  'What are the disadvantages of Laplace transform?',
#  'Will kindle screen harm my eyes while reading from it? Just like any other LED screens?',
#  'What are covalent and ionic bonds? What are some examples?',
#  'Who is behind nattyornot.com?',
#  'Which is a suitable solar panel installation provider near Pasadena, California CA?',
#  'What is a good natural face wash to buy?',
#  "What's Newton's third law?",
#  'How can I upload a video file larger than 3G to Youku?',
#  'Is an elephant dangerous?',
#  'Why do people on Quora ask silly questions about the facts which can be googled very easily?',
#  'What are the habits of highly successful people?',
#  'How can I practice driving without owning a car?',
#  'How do you determine the surface area of cuboid?',
#  "What is the scariest paranormal experience you've ever had?",
#  'What are the best scenes and quotes from "After Earth"?',
#  'What is your biggest hopeless regret?',
#  'Why are grad students often so secretive when describing their research to undergrads?',
#  'How do amazon get tracking details from speed post?',
#  'Do we get more VMC modules in class 12?',
#  'What are some logical questions and answers which are asked by HR?',
#  'Can being in and out of relationships a lot make a person depressed?',
#  'What are the best quotes you ever listened?',
#  'Queen (band): How many years did Freddie Mercury take to create Bohemian Rhapsody?',
#  'How many atheists are there on Quora?',
#  'What is personal growth?',
#  'How do scientist test a hypothesis? How good are these methods?',
#  'Should I use Amazon EC2/S3 or Dreamhost for web hosting?',
#  'Is history considered to be a social science? If so, why?',
#  'What is the best bicycle to buy under 10k?',
#  'What is the best Mature Linux distro for beginners to advanced users?',
#  'Does masturbation affect fertility?',
#  'How do you earn emergency money?',
#  'How do you make risotto?',
#  'How much it cost to be an Endeavor entrepreneur ?',
#  'How can I secretly take screenshots on Snapchat?',
#  'Should the US military leave Europe?',
#  'Why do some people love to sleep so much?',
#  'How much do you earn a year and what do you do?',
#  'How can I change my profile picture on Quora?',
#  'Can I get a restraining order against someone so they stop calling me?',
#  'What is the expansion of (1-x) ^-4?',
#  'Which is the best coaching centre in Hyderabad for IAS coaching?',
#  'Has the grade pay for an assistant section officer in CSS lowered to 4200 from 4600?',
#  'How do I start a conversation on a public transport?',
#  'How would you complete the sentence, "Run, it\'s a..."?',
#  'How would I know if you were in love with me?',
#  'Is there no cure for autism?',
#  'Why would reflection be possible and how significant it is to science?',
#  'Is it safe to smoke weed?',
#  'What are the goals of porn industry?',
#  "My reason to why I fear dying is not because I'd miss a day I wouldn't live, but because I'd miss every day I lived. Is it a pessimistic view of life?",
#  'Where can I purchase windows 8.1?',
#  'My paytm transaction failed but amount was debited. How do I solve this issue?',
#  'What will we need to do to learn if Proxima b is habitable?',
#  'A and B are two independent events. P( A and B) =1/6 and the probability that neither of them occur is 1/3. Find the probability occurrence of A?',
#  'Why is it recommended to eject the USB safely before removing it physically?',
#  'What is the ideal way of loosing weight?',
#  'Where can I find best hotels in Nainital?',
#  'What is the taste of human semen?',
#  'What can I do with interior designing after a mechanical engineering? I am interested in this too.',
#  'Did Russian medics use morphine during WW1?',
#  'Is Putin a good guy or bad guy?',
#  'How can I learn digital marketing?',
#  'What can I do to improve myself every day?',
#  "Why don't Indian government promote one child policy like China did to control the population?",
#  "How realistic is Elon Musk's plan for SpaceX to colonise Mars?",
#  'If I am bipolar should I take meds and what if I can’t work?',
#  'Does pure love really exist?',
#  "Why can't India establish one or two child policy?",
#  "What's it like living abroad in Hong Kong?",
#  'What are the greatest movies I have to see?',
#  'What is the difference between truths and beliefs?',
#  'Why are startups so successful in India?',
#  "Would a tourist driving in the US need an international driver's license?",
#  'What are the best places to ski in South America?',
#  'What do coed hostels mean?',
#  'Will Donald Trump or Hillary Clinton win the 2016 US presidential election?',
#  'How can I start a gym?',
#  'How often should I text my crush (every day, two days, once a week)?',
#  'Are there nuclear weapons in space?',
#  'What would have happened to Gollum if the Ring was destroyed while he was still alive?',
#  'As a teen, all the songs that I really like turn out to be old (70s-80s music). How do I fix this problem?',
#  'What is Hanes underwear made of?',
#  'What universities does Oceaneering International recruit new grads from? What majors are they looking for?',
#  'How do engineers get promoted at Google?',
#  'Who are the 2016 Top Writers?',
#  'How do you tie a simply tie?',
#  ...]

# %%
pinecone.delete_index(index_name)
